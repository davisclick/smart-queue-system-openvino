# %% [markdown]
# # Smart Queue Monitoring System - Manufacturing Scenario
#
# ## Overview
# Now that you have your Python script and job submission script, you're ready to request an **IEI Tank-870** edge node and run inference on the different hardware types (CPU, GPU, VPU, FPGA).
#
# After the inference is completed, the output video and stats files need to be retrieved and stored in the workspace, which can then be viewed within the Jupyter Notebook.
#
# ## Objectives
# * Submit inference jobs to Intel's DevCloud using the `qsub` command.
# * Retrieve and review the results.
# * After testing, go back to the proposal doc and update your original proposed hardware device.

# %% [markdown]
# ## Step 0: Set Up
#
# #### IMPORTANT: Set up paths so we can run Dev Cloud utilities
# You *must* run this every time you enter a Workspace session.
# (Tip: select the cell and use **Shift+Enter** to run the cell.)

# %%
# %env PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support
import os
import sys
sys.path.insert(0, os.path.abspath('/opt/intel_devcloud_support'))
sys.path.insert(0, os.path.abspath('/opt/intel'))
# Out:
# env: PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support

# %% [markdown]
# ### Step 0.1:  (Optional-step): Original Video
#
# If you are curious to see the input video, run the following cell to view the original video stream we'll be using for inference.

# %%
import videoHtml
videoHtml.videoHTML('Manufacturing', ['original_videos/Manufacturing.mp4'])
# Out:
# <h5>Manufacturing</h5>
#         <video alt="" controls autoplay muted height="480"><source src="original_videos/Manufacturing.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1 : Inference on a Video
#
# In the next few cells, You'll submit your job using the `qsub` command and retrieve the results for each job. Each of the cells below should submit a job to different edge compute nodes.
#
# The output of the cell is the `JobID` of your job, which you can use to track progress of a job with `liveQStat`.
#
# You will need to submit a job for each of the following hardware types:
# * **CPU**
# * **GPU**
# * **VPU**
# * **FPGA**
#
# **Note:** You will have to submit each job one at a time and retrieve their results.
#
# After submission, they will go into a queue and run as soon as the requested compute resources become available.
# (Tip: **shift+enter** will run the cell and automatically move you to the next cell.)
#
# If your job successfully runs and completes, once you retrieve your results, it should output a video and a stats text file in the `results/manufacturing/<DEVICE>` directory.
#
# For example, your **CPU** job should output its files in this directory:
# > **results/manufacturing/cpu**
#
# **Note**: To get the queue labels for the different hardware devices, you can go to [this link](https://devcloud.intel.com/edge/get_started/devcloud/).
#
# The following arguments should be passed to the job submission script after the `-F` flag:
# * Model path - `/data/models/intel/person-detection-retail-0013/<MODEL PRECISION>/`. You will need to adjust this path based on the model precision being using on the hardware.
# * Device - `CPU`, `GPU`, `MYRIAD`, `HETERO:FPGA,CPU`.
# * Manufacturing video path - `/data/resources/manufacturing.mp4`.
# * Manufacturing queue_param file path - `/data/queue_param/manufacturing.npy`.
# * Output path - `/output/results/manufacturing/<DEVICE>` This should be adjusted based on the device used in the job.
# * Max num of people - This is the max number of people in queue before the system would redirect them to another queue.

# %% [markdown]
# ## Step 1.1: Submit to an Edge Compute Node with an Intel CPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a
#     href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500TE processor</a>. The inference workload should run on the CPU.

# %%
#Submit job to the queue
cpu_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/cpu 5"

print(cpu_job_id[0])
# Out:
# 2yb9xcT39qRJ35W95ycOyMSdDeaHKU9G

# %% [markdown]
# #### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(cpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:2yb9xcT39qRJ35W95ycOyMSdDeaHKU9G) are ready.
# Please wait............................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Queues len:  2
# Coords len:  7
# Coord: [593. 265. 869. 937.]
# Queue: [ 15 180 730 780]
# Coord: [593. 265. 869. 937.]
# Queue: [ 921  144 1424  704]
# Coord: [ 972.  236. 1279.  886.]
# Queue: [ 15 180 730 780]
# Coord: [ 972.  236. 1279.  886.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:972.0 > 921
# coord[2]<q[2]:1279.0 < 1424
# Coord: [  96.  280.  424. 1051.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:96.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  96.  280.  424. 1051.]
# Queue: [ 921  144 1424  704]
# Coord: [1281.  260. 1492.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1281.  260. 1492.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  270. 1773.  745.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  270. 1773.  745.]
# Queue: [ 921  144 1424  704]
# Coord: [1428.  245. 1551.  638.]
# Queue: [ 15 180 730 780]
# Coord: [1428.  245. 1551.  638.]
# Queue: [ 921  144 1424  704]
# Coord: [1774.  269. 1909.  607.]
# Queue: [ 15 180 730 780]
# Coord: [1774.  269. 1909.  607.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [593. 264. 869. 940.]
# Queue: [ 15 180 730 780]
# Coord: [593. 264. 869. 940.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  282.  425. 1051.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  95.  282.  425. 1051.]
# Queue: [ 921  144 1424  704]
# Coord: [ 968.  233. 1278.  889.]
# Queue: [ 15 180 730 780]
# Coord: [ 968.  233. 1278.  889.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:968.0 > 921
# coord[2]<q[2]:1278.0 < 1424
# Coord: [1281.  260. 1493.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1281.  260. 1493.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1527.  272. 1770.  746.]
# Queue: [ 15 180 730 780]
# Coord: [1527.  272. 1770.  746.]
# Queue: [ 921  144 1424  704]
# Coord: [1429.  243. 1553.  637.]
# Queue: [ 15 180 730 780]
# Coord: [1429.  243. 1553.  637.]
# Queue: [ 921  144 1424  704]
# Coord: [1776.  269. 1910.  606.]
# Queue: [ 15 180 730 780]
# Coord: [1776.  269. 1910.  606.]
# Queue: [ 921  144 1424  704]
# Coord: [1730.  273. 1837.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1730.  273. 1837.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [593. 264. 869. 940.]
# Queue: [ 15 180 730 780]
# Coord: [593. 264. 869. 940.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  283.  425. 1050.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  95.  283.  425. 1050.]
# Queue: [ 921  144 1424  704]
# Coord: [ 966.  234. 1280.  888.]
# Queue: [ 15 180 730 780]
# Coord: [ 966.  234. 1280.  888.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:966.0 > 921
# coord[2]<q[2]:1280.0 < 1424
# Coord: [1280.  258. 1493.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  258. 1493.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1526.  272. 1771.  744.]
# Queue: [ 15 180 730 780]
# Coord: [1526.  272. 1771.  744.]
# Queue: [ 921  144 1424  704]
# Coord: [1427.  246. 1552.  637.]
# Queue: [ 15 180 730 780]
# Coord: [1427.  246. 1552.  637.]
# Queue: [ 921  144 1424  704]
# Coord: [1778.  269. 1912.  607.]
# Queue: [ 15 180 730 780]
# Coord: [1778.  269. 1912.  607.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  272. 1837.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  272. 1837.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [593. 264. 868. 942.]
# Queue: [ 15 180 730 780]
# Coord: [593. 264. 868. 942.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  282.  424. 1051.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  282.  424. 1051.]
# Queue: [ 921  144 1424  704]
# Coord: [ 970.  232. 1287.  884.]
# Queue: [ 15 180 730 780]
# Coord: [ 970.  232. 1287.  884.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:970.0 > 921
# coord[2]<q[2]:1287.0 < 1424
# Coord: [1279.  256. 1496.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  256. 1496.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1433.  239. 1552.  633.]
# Queue: [ 15 180 730 780]
# Coord: [1433.  239. 1552.  633.]
# Queue: [ 921  144 1424  704]
# Coord: [1522.  272. 1771.  746.]
# Queue: [ 15 180 730 780]
# Coord: [1522.  272. 1771.  746.]
# Queue: [ 921  144 1424  704]
# Coord: [1781.  266. 1913.  608.]
# Queue: [ 15 180 730 780]
# Coord: [1781.  266. 1913.  608.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  271. 1836.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  271. 1836.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [592. 264. 868. 948.]
# Queue: [ 15 180 730 780]
# Coord: [592. 264. 868. 948.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  282.  425. 1048.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  282.  425. 1048.]
# Queue: [ 921  144 1424  704]
# Coord: [ 970.  233. 1287.  883.]
# Queue: [ 15 180 730 780]
# Coord: [ 970.  233. 1287.  883.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:970.0 > 921
# coord[2]<q[2]:1287.0 < 1424
# Coord: [1278.  255. 1496.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1496.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1434.  239. 1551.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1434.  239. 1551.  632.]
# Queue: [ 921  144 1424  704]
# Coord: [1521.  273. 1770.  746.]
# Queue: [ 15 180 730 780]
# Coord: [1521.  273. 1770.  746.]
# Queue: [ 921  144 1424  704]
# Coord: [1782.  267. 1913.  611.]
# Queue: [ 15 180 730 780]
# Coord: [1782.  267. 1913.  611.]
# Queue: [ 921  144 1424  704]
# Coord: [1728.  269. 1837.  572.]
# Queue: [ 15 180 730 780]
# Coord: [1728.  269. 1837.  572.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [591. 264. 867. 944.]
# Queue: [ 15 180 730 780]
# Coord: [591. 264. 867. 944.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  282.  425. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  93.  282.  425. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [ 977.  233. 1291.  878.]
# Queue: [ 15 180 730 780]
# Coord: [ 977.  233. 1291.  878.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:977.0 > 921
# coord[2]<q[2]:1291.0 < 1424
# Coord: [1277.  255. 1498.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1277.  255. 1498.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1434.  238. 1552.  633.]
# Queue: [ 15 180 730 780]
# Coord: [1434.  238. 1552.  633.]
# Queue: [ 921  144 1424  704]
# Coord: [1526.  272. 1769.  747.]
# Queue: [ 15 180 730 780]
# Coord: [1526.  272. 1769.  747.]
# Queue: [ 921  144 1424  704]
# Coord: [1781.  266. 1913.  608.]
# Queue: [ 15 180 730 780]
# Coord: [1781.  266. 1913.  608.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  270. 1837.  571.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  270. 1837.  571.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [591. 265. 869. 941.]
# Queue: [ 15 180 730 780]
# Coord: [591. 265. 869. 941.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  283.  425. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  93.  283.  425. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [ 967.  232. 1290.  877.]
# Queue: [ 15 180 730 780]
# Coord: [ 967.  232. 1290.  877.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:967.0 > 921
# coord[2]<q[2]:1290.0 < 1424
# Coord: [1278.  256. 1501.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  256. 1501.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1523.  272. 1768.  747.]
# Queue: [ 15 180 730 780]
# Coord: [1523.  272. 1768.  747.]
# Queue: [ 921  144 1424  704]
# Coord: [1433.  239. 1551.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1433.  239. 1551.  632.]
# Queue: [ 921  144 1424  704]
# Coord: [1781.  268. 1913.  608.]
# Queue: [ 15 180 730 780]
# Coord: [1781.  268. 1913.  608.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  270. 1837.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  270. 1837.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [591. 267. 870. 943.]
# Queue: [ 15 180 730 780]
# Coord: [591. 267. 870. 943.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  282.  425. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  93.  282.  425. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [ 973.  233. 1289.  876.]
# Queue: [ 15 180 730 780]
# Coord: [ 973.  233. 1289.  876.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:973.0 > 921
# coord[2]<q[2]:1289.0 < 1424
# Coord: [1278.  255. 1500.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1500.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1527.  270. 1767.  748.]
# Queue: [ 15 180 730 780]
# Coord: [1527.  270. 1767.  748.]
# Queue: [ 921  144 1424  704]
# Coord: [1433.  240. 1550.  633.]
# Queue: [ 15 180 730 780]
# Coord: [1433.  240. 1550.  633.]
# Queue: [ 921  144 1424  704]
# Coord: [1780.  267. 1913.  608.]
# Queue: [ 15 180 730 780]
# Coord: [1780.  267. 1913.  608.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  270. 1837.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  270. 1837.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [591. 267. 870. 943.]
# Queue: [ 15 180 730 780]
# Coord: [591. 267. 870. 943.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  282.  425. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  93.  282.  425. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [ 975.  232. 1286.  876.]
# Queue: [ 15 180 730 780]
# Coord: [ 975.  232. 1286.  876.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:975.0 > 921
# coord[2]<q[2]:1286.0 < 1424
# Coord: [1279.  255. 1498.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  255. 1498.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  272. 1767.  746.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  272. 1767.  746.]
# Queue: [ 921  144 1424  704]
# Coord: [1435.  242. 1550.  641.]
# Queue: [ 15 180 730 780]
# Coord: [1435.  242. 1550.  641.]
# Queue: [ 921  144 1424  704]
# Coord: [1782.  266. 1914.  605.]
# Queue: [ 15 180 730 780]
# Coord: [1782.  266. 1914.  605.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  270. 1839.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  270. 1839.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [592. 266. 868. 944.]
# Queue: [ 15 180 730 780]
# Coord: [592. 266. 868. 944.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  283.  425. 1059.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  283.  425. 1059.]
# Queue: [ 921  144 1424  704]
# Coord: [ 965.  233. 1285.  877.]
# Queue: [ 15 180 730 780]
# Coord: [ 965.  233. 1285.  877.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:965.0 > 921
# coord[2]<q[2]:1285.0 < 1424
# Coord: [1280.  256. 1499.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  256. 1499.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  271. 1767.  749.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  271. 1767.  749.]
# Queue: [ 921  144 1424  704]
# Coord: [1435.  253. 1550.  637.]
# Queue: [ 15 180 730 780]
# Coord: [1435.  253. 1550.  637.]
# Queue: [ 921  144 1424  704]
# Coord: [1783.  264. 1916.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1783.  264. 1916.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  271. 1839.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  271. 1839.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  9
# Coord: [591. 264. 871. 944.]
# Queue: [ 15 180 730 780]
# Coord: [591. 264. 871. 944.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  284.  424. 1060.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  94.  284.  424. 1060.]
# Queue: [ 921  144 1424  704]
# Coord: [ 968.  232. 1285.  877.]
# Queue: [ 15 180 730 780]
# Coord: [ 968.  232. 1285.  877.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:968.0 > 921
# coord[2]<q[2]:1285.0 < 1424
# Coord: [1278.  255. 1498.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1498.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  271. 1766.  751.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  271. 1766.  751.]
# Queue: [ 921  144 1424  704]
# Coord: [1784.  262. 1917.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1784.  262. 1917.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1436.  258. 1547.  634.]
# Queue: [ 15 180 730 780]
# Coord: [1436.  258. 1547.  634.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  272. 1837.  572.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  272. 1837.  572.]
# Queue: [ 921  144 1424  704]
# Coord: [1208.  257. 1235.  316.]
# Queue: [ 15 180 730 780]
# Coord: [1208.  257. 1235.  316.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1208.0 > 921
# coord[2]<q[2]:1235.0 < 1424
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [591. 262. 870. 946.]
# Queue: [ 15 180 730 780]
# Coord: [591. 262. 870. 946.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  283.  430. 1060.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:430.0 < 730
# Coord: [  93.  283.  430. 1060.]
# Queue: [ 921  144 1424  704]
# Coord: [ 962.  234. 1284.  878.]
# Queue: [ 15 180 730 780]
# Coord: [ 962.  234. 1284.  878.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:962.0 > 921
# coord[2]<q[2]:1284.0 < 1424
# Coord: [1279.  254. 1499.  837.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  254. 1499.  837.]
# Queue: [ 921  144 1424  704]
# Coord: [1537.  273. 1766.  752.]
# Queue: [ 15 180 730 780]
# Coord: [1537.  273. 1766.  752.]
# Queue: [ 921  144 1424  704]
# Coord: [1785.  261. 1917.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1785.  261. 1917.  603.]
# Queue: [ 921  144 1424  704]
# Coord: [1436.  261. 1549.  633.]
# Queue: [ 15 180 730 780]
# Coord: [1436.  261. 1549.  633.]
# Queue: [ 921  144 1424  704]
# Coord: [1721.  271. 1835.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1721.  271. 1835.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [593. 261. 869. 952.]
# Queue: [ 15 180 730 780]
# Coord: [593. 261. 869. 952.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  285.  425. 1059.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  285.  425. 1059.]
# Queue: [ 921  144 1424  704]
# Coord: [ 962.  234. 1282.  875.]
# Queue: [ 15 180 730 780]
# Coord: [ 962.  234. 1282.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:962.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [1278.  254. 1499.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  254. 1499.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1537.  271. 1766.  749.]
# Queue: [ 15 180 730 780]
# Coord: [1537.  271. 1766.  749.]
# Queue: [ 921  144 1424  704]
# Coord: [1787.  259. 1919.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1787.  259. 1919.  603.]
# Queue: [ 921  144 1424  704]
# Coord: [1437.  264. 1548.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1437.  264. 1548.  632.]
# Queue: [ 921  144 1424  704]
# Coord: [1718.  271. 1833.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1718.  271. 1833.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [597. 258. 865. 953.]
# Queue: [ 15 180 730 780]
# Coord: [597. 258. 865. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  284.  424. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  284.  424. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [ 964.  233. 1284.  875.]
# Queue: [ 15 180 730 780]
# Coord: [ 964.  233. 1284.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:964.0 > 921
# coord[2]<q[2]:1284.0 < 1424
# Coord: [1278.  260. 1499.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  260. 1499.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1539.  275. 1771.  745.]
# Queue: [ 15 180 730 780]
# Coord: [1539.  275. 1771.  745.]
# Queue: [ 921  144 1424  704]
# Coord: [1788.  259. 1918.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1788.  259. 1918.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1719.  272. 1833.  575.]
# Queue: [ 15 180 730 780]
# Coord: [1719.  272. 1833.  575.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [600. 258. 861. 952.]
# Queue: [ 15 180 730 780]
# Coord: [600. 258. 861. 952.]
# Queue: [ 921  144 1424  704]
# Coord: [  96.  284.  424. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:96.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  96.  284.  424. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [ 957.  235. 1282.  875.]
# Queue: [ 15 180 730 780]
# Coord: [ 957.  235. 1282.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:957.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [1275.  254. 1499.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  254. 1499.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1539.  274. 1770.  743.]
# Queue: [ 15 180 730 780]
# Coord: [1539.  274. 1770.  743.]
# Queue: [ 921  144 1424  704]
# Coord: [1788.  260. 1917.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1788.  260. 1917.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1720.  274. 1833.  575.]
# Queue: [ 15 180 730 780]
# Coord: [1720.  274. 1833.  575.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [607. 273. 860. 953.]
# Queue: [ 15 180 730 780]
# Coord: [607. 273. 860. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [  96.  285.  424. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:96.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  96.  285.  424. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [ 956.  235. 1280.  876.]
# Queue: [ 15 180 730 780]
# Coord: [ 956.  235. 1280.  876.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:956.0 > 921
# coord[2]<q[2]:1280.0 < 1424
# Coord: [1277.  255. 1499.  837.]
# Queue: [ 15 180 730 780]
# Coord: [1277.  255. 1499.  837.]
# Queue: [ 921  144 1424  704]
# Coord: [1538.  274. 1769.  745.]
# Queue: [ 15 180 730 780]
# Coord: [1538.  274. 1769.  745.]
# Queue: [ 921  144 1424  704]
# Coord: [1788.  258. 1918.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1788.  258. 1918.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1724.  274. 1831.  570.]
# Queue: [ 15 180 730 780]
# Coord: [1724.  274. 1831.  570.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 958.  234. 1275.  881.]
# Queue: [ 15 180 730 780]
# Coord: [ 958.  234. 1275.  881.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:958.0 > 921
# coord[2]<q[2]:1275.0 < 1424
# Coord: [608. 272. 859. 956.]
# Queue: [ 15 180 730 780]
# Coord: [608. 272. 859. 956.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  285.  424. 1050.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  285.  424. 1050.]
# Queue: [ 921  144 1424  704]
# Coord: [1276.  256. 1500.  837.]
# Queue: [ 15 180 730 780]
# Coord: [1276.  256. 1500.  837.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  275. 1770.  743.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  275. 1770.  743.]
# Queue: [ 921  144 1424  704]
# Coord: [1786.  258. 1918.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1786.  258. 1918.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1722.  273. 1835.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1722.  273. 1835.  573.]
# Queue: [ 921  144 1424  704]
# Coord: [1208.  257. 1235.  316.]
# Queue: [ 15 180 730 780]
# Coord: [1208.  257. 1235.  316.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1208.0 > 921
# coord[2]<q[2]:1235.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [ 964.  231. 1274.  884.]
# Queue: [ 15 180 730 780]
# Coord: [ 964.  231. 1274.  884.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:964.0 > 921
# coord[2]<q[2]:1274.0 < 1424
# Coord: [610. 273. 858. 952.]
# Queue: [ 15 180 730 780]
# Coord: [610. 273. 858. 952.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  284.  424. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  284.  424. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  255. 1500.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  255. 1500.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1533.  275. 1769.  743.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  275. 1769.  743.]
# Queue: [ 921  144 1424  704]
# Coord: [1786.  261. 1914.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1786.  261. 1914.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  271. 1838.  574.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  271. 1838.  574.]
# Queue: [ 921  144 1424  704]
# Coord: [1208.  258. 1234.  316.]
# Queue: [ 15 180 730 780]
# Coord: [1208.  258. 1234.  316.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1208.0 > 921
# coord[2]<q[2]:1234.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  7
# Coord: [ 963.  232. 1274.  885.]
# Queue: [ 15 180 730 780]
# Coord: [ 963.  232. 1274.  885.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:963.0 > 921
# coord[2]<q[2]:1274.0 < 1424
# Coord: [608. 270. 858. 951.]
# Queue: [ 15 180 730 780]
# Coord: [608. 270. 858. 951.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  285.  424. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  285.  424. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  256. 1499.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  256. 1499.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1533.  275. 1767.  745.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  275. 1767.  745.]
# Queue: [ 921  144 1424  704]
# Coord: [1786.  259. 1914.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1786.  259. 1914.  603.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  273. 1837.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  273. 1837.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [ 953.  233. 1272.  881.]
# Queue: [ 15 180 730 780]
# Coord: [ 953.  233. 1272.  881.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:953.0 > 921
# coord[2]<q[2]:1272.0 < 1424
# Coord: [607. 272. 858. 956.]
# Queue: [ 15 180 730 780]
# Coord: [607. 272. 858. 956.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  285.  424. 1053.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  285.  424. 1053.]
# Queue: [ 921  144 1424  704]
# Coord: [1278.  260. 1500.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  260. 1500.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  275. 1769.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  275. 1769.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1787.  258. 1914.  602.]
# Queue: [ 15 180 730 780]
# Coord: [1787.  258. 1914.  602.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  269. 1836.  575.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  269. 1836.  575.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [ 959.  233. 1271.  883.]
# Queue: [ 15 180 730 780]
# Coord: [ 959.  233. 1271.  883.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:959.0 > 921
# coord[2]<q[2]:1271.0 < 1424
# Coord: [607. 271. 858. 957.]
# Queue: [ 15 180 730 780]
# Coord: [607. 271. 858. 957.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  285.  424. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  285.  424. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [1278.  259. 1500.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  259. 1500.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1533.  275. 1766.  744.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  275. 1766.  744.]
# Queue: [ 921  144 1424  704]
# Coord: [1785.  258. 1912.  605.]
# Queue: [ 15 180 730 780]
# Coord: [1785.  258. 1912.  605.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  270. 1837.  574.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  270. 1837.  574.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 961.  234. 1270.  883.]
# Queue: [ 15 180 730 780]
# Coord: [ 961.  234. 1270.  883.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:961.0 > 921
# coord[2]<q[2]:1270.0 < 1424
# Coord: [607. 271. 858. 953.]
# Queue: [ 15 180 730 780]
# Coord: [607. 271. 858. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  285.  425. 1051.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  285.  425. 1051.]
# Queue: [ 921  144 1424  704]
# Coord: [1276.  260. 1502.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1276.  260. 1502.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1536.  275. 1769.  742.]
# Queue: [ 15 180 730 780]
# Coord: [1536.  275. 1769.  742.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  269. 1836.  576.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  269. 1836.  576.]
# Queue: [ 921  144 1424  704]
# Coord: [1785.  257. 1911.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1785.  257. 1911.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1209.  258. 1236.  315.]
# Queue: [ 15 180 730 780]
# Coord: [1209.  258. 1236.  315.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1209.0 > 921
# coord[2]<q[2]:1236.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  7
# Coord: [ 971.  232. 1272.  882.]
# Queue: [ 15 180 730 780]
# Coord: [ 971.  232. 1272.  882.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:971.0 > 921
# coord[2]<q[2]:1272.0 < 1424
# Coord: [607. 272. 857. 955.]
# Queue: [ 15 180 730 780]
# Coord: [607. 272. 857. 955.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  284.  425. 1051.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  284.  425. 1051.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  255. 1502.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  255. 1502.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  275. 1767.  744.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  275. 1767.  744.]
# Queue: [ 921  144 1424  704]
# Coord: [1728.  268. 1833.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1728.  268. 1833.  573.]
# Queue: [ 921  144 1424  704]
# Coord: [1821.  246. 1917.  606.]
# Queue: [ 15 180 730 780]
# Coord: [1821.  246. 1917.  606.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 975.  234. 1272.  886.]
# Queue: [ 15 180 730 780]
# Coord: [ 975.  234. 1272.  886.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:975.0 > 921
# coord[2]<q[2]:1272.0 < 1424
# Coord: [610. 272. 856. 951.]
# Queue: [ 15 180 730 780]
# Coord: [610. 272. 856. 951.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  284.  425. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  284.  425. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  256. 1503.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  256. 1503.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  275. 1770.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  275. 1770.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  270. 1833.  572.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  270. 1833.  572.]
# Queue: [ 921  144 1424  704]
# Coord: [1783.  258. 1910.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1783.  258. 1910.  603.]
# Queue: [ 921  144 1424  704]
# Coord: [1209.  259. 1235.  316.]
# Queue: [ 15 180 730 780]
# Coord: [1209.  259. 1235.  316.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1209.0 > 921
# coord[2]<q[2]:1235.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [ 975.  234. 1275.  889.]
# Queue: [ 15 180 730 780]
# Coord: [ 975.  234. 1275.  889.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:975.0 > 921
# coord[2]<q[2]:1275.0 < 1424
# Coord: [611. 273. 855. 950.]
# Queue: [ 15 180 730 780]
# Coord: [611. 273. 855. 950.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  283.  425. 1053.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:425.0 < 730
# Coord: [  94.  283.  425. 1053.]
# Queue: [ 921  144 1424  704]
# Coord: [1276.  256. 1504.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1276.  256. 1504.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1533.  275. 1768.  741.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  275. 1768.  741.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  270. 1836.  577.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  270. 1836.  577.]
# Queue: [ 921  144 1424  704]
# Coord: [1819.  251. 1917.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1819.  251. 1917.  603.]
# Queue: [ 921  144 1424  704]
# Coord: [1209.  258. 1235.  316.]
# Queue: [ 15 180 730 780]
# Coord: [1209.  258. 1235.  316.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1209.0 > 921
# coord[2]<q[2]:1235.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  7
# Coord: [ 985.  236. 1280.  886.]
# Queue: [ 15 180 730 780]
# Coord: [ 985.  236. 1280.  886.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:985.0 > 921
# coord[2]<q[2]:1280.0 < 1424
# Coord: [614. 271. 856. 950.]
# Queue: [ 15 180 730 780]
# Coord: [614. 271. 856. 950.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  282.  424. 1059.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  94.  282.  424. 1059.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  250. 1505.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  250. 1505.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1531.  274. 1769.  738.]
# Queue: [ 15 180 730 780]
# Coord: [1531.  274. 1769.  738.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  267. 1836.  576.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  267. 1836.  576.]
# Queue: [ 921  144 1424  704]
# Coord: [1784.  261. 1910.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1784.  261. 1910.  603.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [611. 272. 860. 949.]
# Queue: [ 15 180 730 780]
# Coord: [611. 272. 860. 949.]
# Queue: [ 921  144 1424  704]
# Coord: [1004.  239. 1282.  883.]
# Queue: [ 15 180 730 780]
# Coord: [1004.  239. 1282.  883.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1004.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [  95.  282.  424. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  95.  282.  424. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1275.  250. 1505.  839.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  250. 1505.  839.]
# Queue: [ 921  144 1424  704]
# Coord: [1530.  274. 1768.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  274. 1768.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  267. 1832.  572.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  267. 1832.  572.]
# Queue: [ 921  144 1424  704]
# Coord: [1817.  248. 1917.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1817.  248. 1917.  603.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [608. 271. 868. 955.]
# Queue: [ 15 180 730 780]
# Coord: [608. 271. 868. 955.]
# Queue: [ 921  144 1424  704]
# Coord: [1013.  237. 1282.  882.]
# Queue: [ 15 180 730 780]
# Coord: [1013.  237. 1282.  882.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1013.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [  94.  281.  423. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:423.0 < 730
# Coord: [  94.  281.  423. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1274.  255. 1503.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1274.  255. 1503.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1530.  274. 1767.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  274. 1767.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  268. 1833.  572.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  268. 1833.  572.]
# Queue: [ 921  144 1424  704]
# Coord: [1785.  259. 1911.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1785.  259. 1911.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1208.  256. 1235.  319.]
# Queue: [ 15 180 730 780]
# Coord: [1208.  256. 1235.  319.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1208.0 > 921
# coord[2]<q[2]:1235.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  7
# Coord: [610. 265. 879. 956.]
# Queue: [ 15 180 730 780]
# Coord: [610. 265. 879. 956.]
# Queue: [ 921  144 1424  704]
# Coord: [  92.  284.  431. 1059.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:92.0 > 15
# coord[2]<q[2]:431.0 < 730
# Coord: [  92.  284.  431. 1059.]
# Queue: [ 921  144 1424  704]
# Coord: [1017.  236. 1282.  881.]
# Queue: [ 15 180 730 780]
# Coord: [1017.  236. 1282.  881.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1017.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [1276.  251. 1505.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1276.  251. 1505.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1532.  275. 1767.  738.]
# Queue: [ 15 180 730 780]
# Coord: [1532.  275. 1767.  738.]
# Queue: [ 921  144 1424  704]
# Coord: [1728.  266. 1833.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1728.  266. 1833.  573.]
# Queue: [ 921  144 1424  704]
# Coord: [1784.  257. 1910.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1784.  257. 1910.  604.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [610. 261. 893. 966.]
# Queue: [ 15 180 730 780]
# Coord: [610. 261. 893. 966.]
# Queue: [ 921  144 1424  704]
# Coord: [  92.  284.  431. 1059.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:92.0 > 15
# coord[2]<q[2]:431.0 < 730
# Coord: [  92.  284.  431. 1059.]
# Queue: [ 921  144 1424  704]
# Coord: [1020.  236. 1283.  877.]
# Queue: [ 15 180 730 780]
# Coord: [1020.  236. 1283.  877.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1020.0 > 921
# coord[2]<q[2]:1283.0 < 1424
# Coord: [1277.  251. 1505.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1277.  251. 1505.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1532.  274. 1768.  738.]
# Queue: [ 15 180 730 780]
# Coord: [1532.  274. 1768.  738.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  265. 1832.  575.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  265. 1832.  575.]
# Queue: [ 921  144 1424  704]
# Coord: [1438.  270. 1545.  628.]
# Queue: [ 15 180 730 780]
# Coord: [1438.  270. 1545.  628.]
# Queue: [ 921  144 1424  704]
# Coord: [1208.  256. 1236.  318.]
# Queue: [ 15 180 730 780]
# Coord: [1208.  256. 1236.  318.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1208.0 > 921
# coord[2]<q[2]:1236.0 < 1424
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  7
# Coord: [612. 260. 900. 962.]
# Queue: [ 15 180 730 780]
# Coord: [612. 260. 900. 962.]
# Queue: [ 921  144 1424  704]
# Coord: [  94.  282.  424. 1053.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:424.0 < 730
# Coord: [  94.  282.  424. 1053.]
# Queue: [ 921  144 1424  704]
# Coord: [1022.  236. 1283.  876.]
# Queue: [ 15 180 730 780]
# Coord: [1022.  236. 1283.  876.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1022.0 > 921
# coord[2]<q[2]:1283.0 < 1424
# Coord: [1275.  259. 1501.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  259. 1501.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1533.  276. 1768.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  276. 1768.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  266. 1832.  574.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  266. 1832.  574.]
# Queue: [ 921  144 1424  704]
# Coord: [1440.  270. 1548.  630.]
# Queue: [ 15 180 730 780]
# Coord: [1440.  270. 1548.  630.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [612. 261. 905. 960.]
# Queue: [ 15 180 730 780]
# Coord: [612. 261. 905. 960.]
# Queue: [ 921  144 1424  704]
# Coord: [  93.  285.  431. 1060.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:93.0 > 15
# coord[2]<q[2]:431.0 < 730
# Coord: [  93.  285.  431. 1060.]
# Queue: [ 921  144 1424  704]
# Coord: [1018.  235. 1283.  875.]
# Queue: [ 15 180 730 780]
# Coord: [1018.  235. 1283.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1018.0 > 921
# coord[2]<q[2]:1283.0 < 1424
# Coord: [1275.  255. 1501.  840.]
# Queue: [ 15 180 730 780]
# Coord: [1275.  255. 1501.  840.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  275. 1768.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  275. 1768.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1443.  265. 1552.  634.]
# Queue: [ 15 180 730 780]
# Coord: [1443.  265. 1552.  634.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  265. 1835.  574.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  265. 1835.  574.]
# Queue: [ 921  144 1424  704]
# Coord: [1774.  259. 1903.  602.]
# Queue: [ 15 180 730 780]
# Coord: [1774.  259. 1903.  602.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [  92.  289.  433. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:92.0 > 15
# coord[2]<q[2]:433.0 < 730
# Coord: [  92.  289.  433. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [609. 263. 912. 959.]
# Queue: [ 15 180 730 780]
# Coord: [609. 263. 912. 959.]
# Queue: [ 921  144 1424  704]
# Coord: [1013.  234. 1283.  877.]
# Queue: [ 15 180 730 780]
# Coord: [1013.  234. 1283.  877.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1013.0 > 921
# coord[2]<q[2]:1283.0 < 1424
# Coord: [1277.  258. 1501.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1277.  258. 1501.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1535.  276. 1769.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  276. 1769.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  266. 1833.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  266. 1833.  573.]
# Queue: [ 921  144 1424  704]
# Coord: [1778.  259. 1909.  602.]
# Queue: [ 15 180 730 780]
# Coord: [1778.  259. 1909.  602.]
# Queue: [ 921  144 1424  704]
# Coord: [1440.  268. 1548.  631.]
# Queue: [ 15 180 730 780]
# Coord: [1440.  268. 1548.  631.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [  90.  290.  434. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  90.  290.  434. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [609. 266. 906. 960.]
# Queue: [ 15 180 730 780]
# Coord: [609. 266. 906. 960.]
# Queue: [ 921  144 1424  704]
# Coord: [1015.  233. 1282.  875.]
# Queue: [ 15 180 730 780]
# Coord: [1015.  233. 1282.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1015.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [1278.  258. 1501.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  258. 1501.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1530.  276. 1770.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  276. 1770.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1768.  269. 1903.  602.]
# Queue: [ 15 180 730 780]
# Coord: [1768.  269. 1903.  602.]
# Queue: [ 921  144 1424  704]
# Coord: [1440.  268. 1547.  631.]
# Queue: [ 15 180 730 780]
# Coord: [1440.  268. 1547.  631.]
# Queue: [ 921  144 1424  704]
# Coord: [1723.  265. 1841.  581.]
# Queue: [ 15 180 730 780]
# Coord: [1723.  265. 1841.  581.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [1016.  233. 1286.  872.]
# Queue: [ 15 180 730 780]
# Coord: [1016.  233. 1286.  872.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1016.0 > 921
# coord[2]<q[2]:1286.0 < 1424
# Coord: [607. 267. 906. 959.]
# Queue: [ 15 180 730 780]
# Coord: [607. 267. 906. 959.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  289.  434. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  91.  289.  434. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [1279.  259. 1501.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  259. 1501.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1531.  276. 1771.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1531.  276. 1771.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1725.  269. 1843.  582.]
# Queue: [ 15 180 730 780]
# Coord: [1725.  269. 1843.  582.]
# Queue: [ 921  144 1424  704]
# Coord: [1438.  268. 1547.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1438.  268. 1547.  632.]
# Queue: [ 921  144 1424  704]
# Coord: [1761.  273. 1898.  601.]
# Queue: [ 15 180 730 780]
# Coord: [1761.  273. 1898.  601.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [602. 266. 896. 964.]
# Queue: [ 15 180 730 780]
# Coord: [602. 266. 896. 964.]
# Queue: [ 921  144 1424  704]
# Coord: [1014.  233. 1288.  873.]
# Queue: [ 15 180 730 780]
# Coord: [1014.  233. 1288.  873.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1014.0 > 921
# coord[2]<q[2]:1288.0 < 1424
# Coord: [  90.  289.  434. 1060.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  90.  289.  434. 1060.]
# Queue: [ 921  144 1424  704]
# Coord: [1285.  259. 1500.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1285.  259. 1500.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1526.  276. 1771.  739.]
# Queue: [ 15 180 730 780]
# Coord: [1526.  276. 1771.  739.]
# Queue: [ 921  144 1424  704]
# Coord: [1436.  264. 1547.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1436.  264. 1547.  632.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [597. 267. 892. 960.]
# Queue: [ 15 180 730 780]
# Coord: [597. 267. 892. 960.]
# Queue: [ 921  144 1424  704]
# Coord: [1010.  235. 1286.  872.]
# Queue: [ 15 180 730 780]
# Coord: [1010.  235. 1286.  872.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1010.0 > 921
# coord[2]<q[2]:1286.0 < 1424
# Coord: [  94.  288.  434. 1057.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:94.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  94.  288.  434. 1057.]
# Queue: [ 921  144 1424  704]
# Coord: [1285.  257. 1499.  838.]
# Queue: [ 15 180 730 780]
# Coord: [1285.  257. 1499.  838.]
# Queue: [ 921  144 1424  704]
# Coord: [1529.  277. 1772.  739.]
# Queue: [ 15 180 730 780]
# Coord: [1529.  277. 1772.  739.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  270. 1842.  581.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  270. 1842.  581.]
# Queue: [ 921  144 1424  704]
# Coord: [1767.  277. 1901.  603.]
# Queue: [ 15 180 730 780]
# Coord: [1767.  277. 1901.  603.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [1005.  235. 1288.  871.]
# Queue: [ 15 180 730 780]
# Coord: [1005.  235. 1288.  871.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1005.0 > 921
# coord[2]<q[2]:1288.0 < 1424
# Coord: [592. 265. 897. 960.]
# Queue: [ 15 180 730 780]
# Coord: [592. 265. 897. 960.]
# Queue: [ 921  144 1424  704]
# Coord: [  95.  288.  434. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:95.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  95.  288.  434. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1286.  257. 1498.  837.]
# Queue: [ 15 180 730 780]
# Coord: [1286.  257. 1498.  837.]
# Queue: [ 921  144 1424  704]
# Coord: [1527.  276. 1771.  741.]
# Queue: [ 15 180 730 780]
# Coord: [1527.  276. 1771.  741.]
# Queue: [ 921  144 1424  704]
# Coord: [1766.  278. 1899.  604.]
# Queue: [ 15 180 730 780]
# Coord: [1766.  278. 1899.  604.]
# Queue: [ 921  144 1424  704]
# Coord: [1437.  265. 1548.  630.]
# Queue: [ 15 180 730 780]
# Coord: [1437.  265. 1548.  630.]
# Queue: [ 921  144 1424  704]
# Coord: [1728.  266. 1847.  583.]
# Queue: [ 15 180 730 780]
# Coord: [1728.  266. 1847.  583.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [591. 266. 893. 958.]
# Queue: [ 15 180 730 780]
# Coord: [591. 266. 893. 958.]
# Queue: [ 921  144 1424  704]
# Coord: [1005.  235. 1285.  869.]
# Queue: [ 15 180 730 780]
# Coord: [1005.  235. 1285.  869.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1005.0 > 921
# coord[2]<q[2]:1285.0 < 1424
# Coord: [  98.  286.  427. 1047.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:98.0 > 15
# coord[2]<q[2]:427.0 < 730
# Coord: [  98.  286.  427. 1047.]
# Queue: [ 921  144 1424  704]
# Coord: [1281.  258. 1497.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1281.  258. 1497.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1530.  277. 1772.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  277. 1772.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1763.  273. 1898.  598.]
# Queue: [ 15 180 730 780]
# Coord: [1763.  273. 1898.  598.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [1007.  235. 1286.  870.]
# Queue: [ 15 180 730 780]
# Coord: [1007.  235. 1286.  870.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1007.0 > 921
# coord[2]<q[2]:1286.0 < 1424
# Coord: [591. 263. 898. 958.]
# Queue: [ 15 180 730 780]
# Coord: [591. 263. 898. 958.]
# Queue: [ 921  144 1424  704]
# Coord: [ 100.  285.  427. 1050.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:100.0 > 15
# coord[2]<q[2]:427.0 < 730
# Coord: [ 100.  285.  427. 1050.]
# Queue: [ 921  144 1424  704]
# Coord: [1284.  257. 1497.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1284.  257. 1497.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1528.  275. 1772.  738.]
# Queue: [ 15 180 730 780]
# Coord: [1528.  275. 1772.  738.]
# Queue: [ 921  144 1424  704]
# Coord: [1436.  263. 1547.  631.]
# Queue: [ 15 180 730 780]
# Coord: [1436.  263. 1547.  631.]
# Queue: [ 921  144 1424  704]
# Coord: [1729.  268. 1849.  583.]
# Queue: [ 15 180 730 780]
# Coord: [1729.  268. 1849.  583.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [592. 263. 902. 958.]
# Queue: [ 15 180 730 780]
# Coord: [592. 263. 902. 958.]
# Queue: [ 921  144 1424  704]
# Coord: [1005.  235. 1285.  870.]
# Queue: [ 15 180 730 780]
# Coord: [1005.  235. 1285.  870.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1005.0 > 921
# coord[2]<q[2]:1285.0 < 1424
# Coord: [ 103.  284.  426. 1049.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:103.0 > 15
# coord[2]<q[2]:426.0 < 730
# Coord: [ 103.  284.  426. 1049.]
# Queue: [ 921  144 1424  704]
# Coord: [1284.  258. 1494.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1284.  258. 1494.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1531.  275. 1771.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1531.  275. 1771.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1730.  266. 1849.  586.]
# Queue: [ 15 180 730 780]
# Coord: [1730.  266. 1849.  586.]
# Queue: [ 921  144 1424  704]
# Coord: [1434.  263. 1545.  632.]
# Queue: [ 15 180 730 780]
# Coord: [1434.  263. 1545.  632.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [1007.  235. 1286.  870.]
# Queue: [ 15 180 730 780]
# Coord: [1007.  235. 1286.  870.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1007.0 > 921
# coord[2]<q[2]:1286.0 < 1424
# Coord: [593. 262. 905. 954.]
# Queue: [ 15 180 730 780]
# Coord: [593. 262. 905. 954.]
# ...
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1052.0 > 921
# coord[2]<q[2]:1293.0 < 1424
# Coord: [1532.  275. 1770.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1532.  275. 1770.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1422.  265. 1546.  647.]
# Queue: [ 15 180 730 780]
# Coord: [1422.  265. 1546.  647.]
# Queue: [ 921  144 1424  704]
# Coord: [1726.  266. 1832.  575.]
# Queue: [ 15 180 730 780]
# Coord: [1726.  266. 1832.  575.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [  88.  292.  436. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:88.0 > 15
# coord[2]<q[2]:436.0 < 730
# Coord: [  88.  292.  436. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [596. 252. 855. 961.]
# Queue: [ 15 180 730 780]
# Coord: [596. 252. 855. 961.]
# Queue: [ 921  144 1424  704]
# Coord: [1280.  251. 1494.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  251. 1494.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1049.  214. 1292.  865.]
# Queue: [ 15 180 730 780]
# Coord: [1049.  214. 1292.  865.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1049.0 > 921
# coord[2]<q[2]:1292.0 < 1424
# Coord: [1533.  275. 1770.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  275. 1770.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1427.  267. 1550.  646.]
# Queue: [ 15 180 730 780]
# Coord: [1427.  267. 1550.  646.]
# Queue: [ 921  144 1424  704]
# Coord: [1727.  266. 1830.  573.]
# Queue: [ 15 180 730 780]
# Coord: [1727.  266. 1830.  573.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [594. 252. 852. 962.]
# Queue: [ 15 180 730 780]
# Coord: [594. 252. 852. 962.]
# Queue: [ 921  144 1424  704]
# Coord: [  90.  293.  435. 1054.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  90.  293.  435. 1054.]
# Queue: [ 921  144 1424  704]
# Coord: [1279.  251. 1495.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  251. 1495.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1049.  214. 1292.  863.]
# Queue: [ 15 180 730 780]
# Coord: [1049.  214. 1292.  863.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1049.0 > 921
# coord[2]<q[2]:1292.0 < 1424
# Coord: [1535.  276. 1771.  735.]
# Queue: [ 15 180 730 780]
# Coord: [1535.  276. 1771.  735.]
# Queue: [ 921  144 1424  704]
# Coord: [1423.  265. 1545.  644.]
# Queue: [ 15 180 730 780]
# Coord: [1423.  265. 1545.  644.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [592. 253. 854. 958.]
# Queue: [ 15 180 730 780]
# Coord: [592. 253. 854. 958.]
# Queue: [ 921  144 1424  704]
# Coord: [  90.  293.  435. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  90.  293.  435. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [1279.  251. 1497.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1279.  251. 1497.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1044.  218. 1292.  863.]
# Queue: [ 15 180 730 780]
# Coord: [1044.  218. 1292.  863.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1044.0 > 921
# coord[2]<q[2]:1292.0 < 1424
# Coord: [1533.  277. 1770.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1533.  277. 1770.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1421.  268. 1546.  644.]
# Queue: [ 15 180 730 780]
# Coord: [1421.  268. 1546.  644.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [592. 254. 857. 954.]
# Queue: [ 15 180 730 780]
# Coord: [592. 254. 857. 954.]
# Queue: [ 921  144 1424  704]
# Coord: [  90.  293.  435. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  90.  293.  435. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1280.  253. 1496.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  253. 1496.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1041.  214. 1293.  863.]
# Queue: [ 15 180 730 780]
# Coord: [1041.  214. 1293.  863.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1041.0 > 921
# coord[2]<q[2]:1293.0 < 1424
# Coord: [1531.  278. 1770.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1531.  278. 1770.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1421.  270. 1543.  646.]
# Queue: [ 15 180 730 780]
# Coord: [1421.  270. 1543.  646.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [  89.  293.  436. 1057.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:89.0 > 15
# coord[2]<q[2]:436.0 < 730
# Coord: [  89.  293.  436. 1057.]
# Queue: [ 921  144 1424  704]
# Coord: [594. 253. 857. 953.]
# Queue: [ 15 180 730 780]
# Coord: [594. 253. 857. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [1282.  253. 1494.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1282.  253. 1494.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1044.  212. 1293.  865.]
# Queue: [ 15 180 730 780]
# Coord: [1044.  212. 1293.  865.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1044.0 > 921
# coord[2]<q[2]:1293.0 < 1424
# Coord: [1530.  278. 1771.  738.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  278. 1771.  738.]
# Queue: [ 921  144 1424  704]
# Coord: [1427.  271. 1541.  638.]
# Queue: [ 15 180 730 780]
# Coord: [1427.  271. 1541.  638.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  5
# Coord: [593. 254. 861. 950.]
# Queue: [ 15 180 730 780]
# Coord: [593. 254. 861. 950.]
# Queue: [ 921  144 1424  704]
# Coord: [  90.  293.  435. 1057.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  90.  293.  435. 1057.]
# Queue: [ 921  144 1424  704]
# Coord: [1282.  253. 1493.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1282.  253. 1493.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1050.  217. 1294.  865.]
# Queue: [ 15 180 730 780]
# Coord: [1050.  217. 1294.  865.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1050.0 > 921
# coord[2]<q[2]:1294.0 < 1424
# Coord: [1531.  278. 1771.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1531.  278. 1771.  737.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  5
# Coord: [592. 255. 861. 954.]
# Queue: [ 15 180 730 780]
# Coord: [592. 255. 861. 954.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  292.  435. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  91.  292.  435. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1282.  253. 1494.  834.]
# Queue: [ 15 180 730 780]
# Coord: [1282.  253. 1494.  834.]
# Queue: [ 921  144 1424  704]
# Coord: [1042.  219. 1295.  865.]
# Queue: [ 15 180 730 780]
# Coord: [1042.  219. 1295.  865.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1042.0 > 921
# coord[2]<q[2]:1295.0 < 1424
# Coord: [1521.  275. 1771.  739.]
# Queue: [ 15 180 730 780]
# Coord: [1521.  275. 1771.  739.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [593. 255. 860. 954.]
# Queue: [ 15 180 730 780]
# Coord: [593. 255. 860. 954.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  290.  435. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  91.  290.  435. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [1280.  253. 1495.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  253. 1495.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1033.  221. 1294.  865.]
# Queue: [ 15 180 730 780]
# Coord: [1033.  221. 1294.  865.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1033.0 > 921
# coord[2]<q[2]:1294.0 < 1424
# Coord: [1516.  274. 1771.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1516.  274. 1771.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1424.  266. 1548.  637.]
# Queue: [ 15 180 730 780]
# Coord: [1424.  266. 1548.  637.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [593. 253. 862. 953.]
# Queue: [ 15 180 730 780]
# Coord: [593. 253. 862. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  289.  434. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:434.0 < 730
# Coord: [  91.  289.  434. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1278.  255. 1497.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1497.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1031.  220. 1294.  867.]
# Queue: [ 15 180 730 780]
# Coord: [1031.  220. 1294.  867.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1031.0 > 921
# coord[2]<q[2]:1294.0 < 1424
# Coord: [1516.  275. 1771.  740.]
# Queue: [ 15 180 730 780]
# Coord: [1516.  275. 1771.  740.]
# Queue: [ 921  144 1424  704]
# Coord: [1425.  266. 1549.  638.]
# Queue: [ 15 180 730 780]
# Coord: [1425.  266. 1549.  638.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [594. 253. 861. 953.]
# Queue: [ 15 180 730 780]
# Coord: [594. 253. 861. 953.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  289.  435. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  91.  289.  435. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1280.  252. 1497.  835.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  252. 1497.  835.]
# Queue: [ 921  144 1424  704]
# Coord: [1026.  228. 1293.  869.]
# Queue: [ 15 180 730 780]
# Coord: [1026.  228. 1293.  869.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1026.0 > 921
# coord[2]<q[2]:1293.0 < 1424
# Coord: [1520.  275. 1771.  741.]
# Queue: [ 15 180 730 780]
# Coord: [1520.  275. 1771.  741.]
# Queue: [ 921  144 1424  704]
# Coord: [1425.  264. 1549.  639.]
# Queue: [ 15 180 730 780]
# Coord: [1425.  264. 1549.  639.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [594. 252. 860. 954.]
# Queue: [ 15 180 730 780]
# Coord: [594. 252. 860. 954.]
# Queue: [ 921  144 1424  704]
# Coord: [  91.  287.  435. 1055.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  91.  287.  435. 1055.]
# Queue: [ 921  144 1424  704]
# Coord: [1014.  231. 1292.  866.]
# Queue: [ 15 180 730 780]
# Coord: [1014.  231. 1292.  866.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:1014.0 > 921
# coord[2]<q[2]:1292.0 < 1424
# Coord: [1280.  252. 1498.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  252. 1498.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1527.  276. 1771.  739.]
# Queue: [ 15 180 730 780]
# Coord: [1527.  276. 1771.  739.]
# Queue: [ 921  144 1424  704]
# Coord: [1422.  265. 1546.  643.]
# Queue: [ 15 180 730 780]
# Coord: [1422.  265. 1546.  643.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [593. 255. 857. 949.]
# Queue: [ 15 180 730 780]
# Coord: [593. 255. 857. 949.]
# Queue: [ 921  144 1424  704]
# Coord: [ 993.  229. 1291.  875.]
# Queue: [ 15 180 730 780]
# Coord: [ 993.  229. 1291.  875.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:993.0 > 921
# coord[2]<q[2]:1291.0 < 1424
# Coord: [  91.  285.  435. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:91.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  91.  285.  435. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1281.  251. 1501.  836.]
# Queue: [ 15 180 730 780]
# Coord: [1281.  251. 1501.  836.]
# Queue: [ 921  144 1424  704]
# Coord: [1528.  276. 1771.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1528.  276. 1771.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1428.  256. 1542.  624.]
# Queue: [ 15 180 730 780]
# Coord: [1428.  256. 1542.  624.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [593. 256. 858. 947.]
# Queue: [ 15 180 730 780]
# Coord: [593. 256. 858. 947.]
# Queue: [ 921  144 1424  704]
# Coord: [ 974.  226. 1285.  878.]
# Queue: [ 15 180 730 780]
# Coord: [ 974.  226. 1285.  878.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:974.0 > 921
# coord[2]<q[2]:1285.0 < 1424
# Coord: [  90.  282.  435. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:435.0 < 730
# Coord: [  90.  282.  435. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [1280.  252. 1499.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1280.  252. 1499.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  277. 1769.  735.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  277. 1769.  735.]
# Queue: [ 921  144 1424  704]
# Coord: [1426.  254. 1548.  644.]
# Queue: [ 15 180 730 780]
# Coord: [1426.  254. 1548.  644.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [590. 257. 859. 945.]
# Queue: [ 15 180 730 780]
# Coord: [590. 257. 859. 945.]
# Queue: [ 921  144 1424  704]
# Coord: [ 974.  232. 1282.  883.]
# Queue: [ 15 180 730 780]
# Coord: [ 974.  232. 1282.  883.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:974.0 > 921
# coord[2]<q[2]:1282.0 < 1424
# Coord: [  90.  280.  436. 1056.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:436.0 < 730
# Coord: [  90.  280.  436. 1056.]
# Queue: [ 921  144 1424  704]
# Coord: [1278.  255. 1500.  833.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1500.  833.]
# Queue: [ 921  144 1424  704]
# Coord: [1530.  277. 1769.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1530.  277. 1769.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1421.  262. 1549.  647.]
# Queue: [ 15 180 730 780]
# Coord: [1421.  262. 1549.  647.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [590. 258. 856. 945.]
# Queue: [ 15 180 730 780]
# Coord: [590. 258. 856. 945.]
# Queue: [ 921  144 1424  704]
# Coord: [ 968.  234. 1281.  884.]
# Queue: [ 15 180 730 780]
# Coord: [ 968.  234. 1281.  884.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:968.0 > 921
# coord[2]<q[2]:1281.0 < 1424
# Coord: [  90.  281.  436. 1058.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:90.0 > 15
# coord[2]<q[2]:436.0 < 730
# Coord: [  90.  281.  436. 1058.]
# Queue: [ 921  144 1424  704]
# Coord: [1278.  255. 1500.  832.]
# Queue: [ 15 180 730 780]
# Coord: [1278.  255. 1500.  832.]
# Queue: [ 921  144 1424  704]
# Coord: [1532.  277. 1769.  736.]
# Queue: [ 15 180 730 780]
# Coord: [1532.  277. 1769.  736.]
# Queue: [ 921  144 1424  704]
# Coord: [1423.  256. 1549.  643.]
# Queue: [ 15 180 730 780]
# Coord: [1423.  256. 1549.  643.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  6
# Coord: [590. 259. 857. 943.]
# Queue: [ 15 180 730 780]
# Coord: [590. 259. 857. 943.]
# Queue: [ 921  144 1424  704]
# Coord: [  92.  281.  439. 1061.]
# Queue: [ 15 180 730 780]
# People in queue
# coord[0]>q[0]:92.0 > 15
# coord[2]<q[2]:439.0 < 730
# Coord: [  92.  281.  439. 1061.]
# Queue: [ 921  144 1424  704]
# Coord: [ 962.  231. 1278.  886.]
# Queue: [ 15 180 730 780]
# Coord: [ 962.  231. 1278.  886.]
# Queue: [ 921  144 1424  704]
# People in queue
# coord[0]>q[0]:962.0 > 921
# coord[2]<q[2]:1278.0 < 1424
# Coord: [1276.  256. 1497.  831.]
# Queue: [ 15 180 730 780]
# Coord: [1276.  256. 1497.  831.]
# Queue: [ 921  144 1424  704]
# Coord: [1534.  276. 1770.  737.]
# Queue: [ 15 180 730 780]
# Coord: [1534.  276. 1770.  737.]
# Queue: [ 921  144 1424  704]
# Coord: [1420.  263. 1550.  647.]
# Queue: [ 15 180 730 780]
# Coord: [1420.  263. 1550.  647.]
# Queue: [ 921  144 1424  704]
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  0
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/cpu/
# results/manufacturing/cpu/stats.txt
# results/manufacturing/cpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:56: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing CPU', ['results/manufacturing/cpu/output_video.mp4'])
# Out:
# <h5>Manufacturing CPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/cpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.2: Submit to an Edge Compute Node with CPU and IGPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core i5-6500TE</a>. The inference workload should run on the **Intel® HD Graphics 530** integrated GPU.

# %%
#Submit job to the queue
gpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-hd-530 -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 GPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/gpu 5" -N store_core

print(gpu_job_id[0])
# Out:
# fSCVx6I8ghWlYmWlarteEoK8aIG6dYZz

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(gpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:fSCVx6I8ghWlYmWlarteEoK8aIG6dYZz) are ready.
# Please wait...................................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/gpu/
# results/manufacturing/gpu/stats.txt
# results/manufacturing/gpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing GPU', ['results/manufacturing/gpu/output_video.mp4'])
# Out:
# <h5>Manufacturing GPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/gpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.3: Submit to an Edge Compute Node with a Neural Compute Stick 2
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core i5-6500te CPU</a>. The inference workload should run on an <a
#     href="https://software.intel.com/en-us/neural-compute-stick">Intel Neural Compute Stick 2</a> installed in this  node.

# %%
#Submit job to the queue
vpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-ncs2 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 MYRIAD /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/vpu 5" -N store_core 

print(vpu_job_id[0])
# Out:
# n6iDZ5rWFceHUEWY85ecPMtegG0BPxCb

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(vpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:n6iDZ5rWFceHUEWY85ecPMtegG0BPxCb) are ready.
# Please wait..................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/vpu/
# results/manufacturing/vpu/stats.txt
# results/manufacturing/vpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing VPU', ['results/manufacturing/vpu/output_video.mp4'])
# Out:
# <h5>Manufacturing VPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/vpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.4: Submit to an Edge Compute Node with IEI Mustang-F100-A10
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500te CPU</a> . The inference workload will run on the <a href="https://www.ieiworld.com/mustang-f100/en/"> IEI Mustang-F100-A10 </a> FPGA card installed in this node.

# %%
#Submit job to the queue
fpga_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te:iei-mustang-f100-a10 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 HETERO:FPGA,CPU /data/resources/manufacturing.mp4 /data/queue_param/manufacturing.npy /output/results/manufacturing/fpga 5" -N store_core

print(fpga_job_id[0])
# Out:
# WYqD13fo5at1Z38H8Jg1q2Ao3ckF4krD

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(fpga_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:WYqD13fo5at1Z38H8Jg1q2Ao3ckF4krD) are ready.
# Please wait.................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# INTELFPGAOCLSDKROOT is not set
# Using script's current directory (/opt/altera/aocl-pro-rte/aclrte-linux64)
#
# aoc was not found, but aocl was found. Assuming only RTE is installed.
#
# AOCL_BOARD_PACKAGE_ROOT is set to /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2. Using that.
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/bin to PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/host/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/lib to LD_LIBRARY_PATH
# aocl program: Running program from /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/libexec
# Programming device: a10gx_2ddr : Intel Vision Accelerator Design with Intel Arria 10 FPGA (acla10_1150_sg20)
# Program succeed.
# Loading Network...
# Network loaded.
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/manufacturing/
# results/manufacturing/fpga/
# results/manufacturing/fpga/stats.txt
# results/manufacturing/fpga/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging.

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Manufacturing FPGA', ['results/manufacturing/fpga/output_video.mp4'])
# Out:
# <h5>Manufacturing FPGA</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/manufacturing/fpga/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ***Wait!***
#
# Please wait for all the inference jobs and video rendering to complete before proceeding to the next step.
#
# ## Step 2: Assess Performance
#
# Run the cells below to compare the performance across all 4 devices. The following timings for the model are being compared across all 4 devices:
#
# - Model Loading Time
# - Average Inference Time
# - FPS

# %%
import matplotlib.pyplot as plt

device_list=['cpu', 'gpu', 'fpga', 'vpu']
inference_time=[]
fps=[]
model_load_time=[]

for device in device_list:
    with open('results/manufacturing/'+device+'/stats.txt', 'r') as f:
        inference_time.append(float(f.readline().split("\n")[0]))
        fps.append(float(f.readline().split("\n")[0]))
        model_load_time.append(float(f.readline().split("\n")[0]))

# %%
plt.bar(device_list, fps)
plt.xlabel("Device Used")
plt.ylabel("Frames per Second")
plt.show()

# %%
plt.bar(device_list, model_load_time)
plt.xlabel("Device Used")
plt.ylabel("Model Loading Time in Seconds")
plt.show()

# %% [markdown]
# # Step 3: Update Proposal Document
#
# Now that you've completed your hardware testing, you should go back to the proposal document and validate or update your originally proposed hardware. Once you've updated your proposal, you can move on to the next scenario.

# %%
plt.bar(device_list, inference_time)
plt.xlabel("Device Used")
plt.ylabel("Total Inference Time in Seconds")
plt.show()
