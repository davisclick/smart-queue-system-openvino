# %% [markdown]
# # Smart Queue Monitoring System - Transportation Scenario
#
# ## Overview
# Now that you have your Python script and job submission script, you're ready to request an **IEI Tank-870** edge node and run inference on the different hardware types (CPU, GPU, VPU, FPGA).
#
# After the inference is completed, the output video and stats files need to be retrieved and stored in the workspace, which can then be viewed within the Jupyter Notebook.
#
# ## Objectives
# * Submit inference jobs to Intel's DevCloud using the `qsub` command.
# * Retrieve and review the results.
# * After testing, go back to the proposal doc and update your original proposed hardware device.

# %% [markdown]
# ## Step 0: Set Up
#
# #### IMPORTANT: Set up paths so we can run Dev Cloud utilities
# You *must* run this every time you enter a Workspace session.
# (Tip: select the cell and use **Shift+Enter** to run the cell.)

# %%
# %env PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support
import os
import sys
sys.path.insert(0, os.path.abspath('/opt/intel_devcloud_support'))
sys.path.insert(0, os.path.abspath('/opt/intel'))
# Out:
# env: PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support

# %% [markdown]
# ### Step 0.1:  (Optional-step): Original Video
#
# If you are curious to see the input video, run the following cell to view the original video stream we'll be using for inference.

# %%
import videoHtml
videoHtml.videoHTML('Transportation', ['original_videos/Transportation.mp4'])
# Out:
# <h5>Transportation</h5>
#         <video alt="" controls autoplay muted height="480"><source src="original_videos/Transportation.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1 : Inference on a Video
#
# In the next few cells, You'll submit your job using the `qsub` command and retrieving the results for each job. Each of the cells below should submit a job to different edge compute nodes.
#
# The output of the cell is the `JobID` of your job, which you can use to track progress of a job with `liveQStat`.
#
# You will need to submit a job for each of the following hardware types:
# * **CPU**
# * **GPU**
# * **VPU**
# * **FPGA**
#
# **Note:** You will have to submit each job one at a time and retrieve their results.
#
# After submission, they will go into a queue and run as soon as the requested compute resources become available.
# (Tip: **shift+enter** will run the cell and automatically move you to the next cell.)
#
# If your job successfully runs and completes, once you retrieve your results, it should output a video and a stats text file in the `results/transportation/<DEVICE>` directory.
#
# For example, your **CPU** job should output its files in this directory:
# > **results/transportation/cpu**
#
# **Note**: To get the queue labels for the different hardware devices, you can go to [this link](https://devcloud.intel.com/edge/get_started/devcloud/).
#
# The following arguments should be passed to the job submission script after the `-F` flag:
# * Model path - `/data/models/intel/person-detection-retail-0013/<MODEL PRECISION>/`. You will need to adjust this path based on the model precision being using on the hardware.
# * Device - `CPU`, `GPU`, `MYRIAD`, `HETERO:FPGA,CPU`
# * Manufacturing video path - `/data/resources/transportation.mp4`
# * Manufacturing queue_param file path - `/data/queue_param/transportation.npy`
# * Output path - `/output/results/transportation/<DEVICE>` This should be adjusted based on the device used in the job.
# * Max num of people - This is the max number of people in queue before the system would redirect them to another queue.

# %% [markdown]
# ## Step 1.1: Submit to an Edge Compute Node with an Intel® CPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a
#     href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core™ i5-6500TE processor</a>. The inference workload should run on the CPU.

# %%
#Submit job to the queue
cpu_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 CPU /data/resources/transportation.mp4 /data/queue_param/transportation.npy /output/results/transportation/cpu 7" -N store_core

print(cpu_job_id[0])
# Out:
# HE2LPIQ4DOWEbongXn9PSEjN234NeVkK

# %% [markdown]
# #### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(cpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:HE2LPIQ4DOWEbongXn9PSEjN234NeVkK) are ready.
# Please wait...........................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Queues len:  2
# Coords len:  8
# Coord: [ 167.  169.  420. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:167.0 > 50
# coord[2]>q[2]:420.0 < 838
# Coord: [ 167.  169.  420. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:167.0 > 852
# coord[2]>q[2]:420.0 < 1430
# Coord: [ 792.   91. 1078.  964.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:792.0 > 50
# coord[2]>q[2]:1078.0 < 838
# Coord: [ 792.   91. 1078.  964.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:792.0 > 852
# coord[2]>q[2]:1078.0 < 1430
# Coord: [568. 137. 874. 993.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:568.0 > 50
# coord[2]>q[2]:874.0 < 838
# Coord: [568. 137. 874. 993.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:568.0 > 852
# coord[2]>q[2]:874.0 < 1430
# Coord: [1486.  146. 1745. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1486.0 > 50
# coord[2]>q[2]:1745.0 < 838
# Coord: [1486.  146. 1745. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1486.0 > 852
# coord[2]>q[2]:1745.0 < 1430
# Coord: [382. 109. 668. 976.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:382.0 > 50
# coord[2]>q[2]:668.0 < 838
# Coord: [382. 109. 668. 976.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:382.0 > 852
# coord[2]>q[2]:668.0 < 1430
# Coord: [1312.  173. 1552. 1020.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1312.0 > 50
# coord[2]>q[2]:1552.0 < 838
# Coord: [1312.  173. 1552. 1020.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1312.0 > 852
# coord[2]>q[2]:1552.0 < 1430
# Coord: [1213.  159. 1442. 1048.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1213.0 > 50
# coord[2]>q[2]:1442.0 < 838
# Coord: [1213.  159. 1442. 1048.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1213.0 > 852
# coord[2]>q[2]:1442.0 < 1430
# Coord: [1580.  134. 1845.  998.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1580.0 > 50
# coord[2]>q[2]:1845.0 < 838
# Coord: [1580.  134. 1845.  998.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1580.0 > 852
# coord[2]>q[2]:1845.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 167.  169.  420. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:167.0 > 50
# coord[2]>q[2]:420.0 < 838
# Coord: [ 167.  169.  420. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:167.0 > 852
# coord[2]>q[2]:420.0 < 1430
# Coord: [ 792.   91. 1078.  962.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:792.0 > 50
# coord[2]>q[2]:1078.0 < 838
# Coord: [ 792.   91. 1078.  962.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:792.0 > 852
# coord[2]>q[2]:1078.0 < 1430
# Coord: [567. 138. 874. 993.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:567.0 > 50
# coord[2]>q[2]:874.0 < 838
# Coord: [567. 138. 874. 993.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:567.0 > 852
# coord[2]>q[2]:874.0 < 1430
# Coord: [1485.  147. 1745. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1485.0 > 50
# coord[2]>q[2]:1745.0 < 838
# Coord: [1485.  147. 1745. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1485.0 > 852
# coord[2]>q[2]:1745.0 < 1430
# Coord: [380. 108. 667. 977.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:380.0 > 50
# coord[2]>q[2]:667.0 < 838
# Coord: [380. 108. 667. 977.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:380.0 > 852
# coord[2]>q[2]:667.0 < 1430
# Coord: [1312.  174. 1551. 1020.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1312.0 > 50
# coord[2]>q[2]:1551.0 < 838
# Coord: [1312.  174. 1551. 1020.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1312.0 > 852
# coord[2]>q[2]:1551.0 < 1430
# Coord: [1213.  159. 1442. 1047.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1213.0 > 50
# coord[2]>q[2]:1442.0 < 838
# Coord: [1213.  159. 1442. 1047.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1213.0 > 852
# coord[2]>q[2]:1442.0 < 1430
# Coord: [1580.  132. 1844.  997.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1580.0 > 50
# coord[2]>q[2]:1844.0 < 838
# Coord: [1580.  132. 1844.  997.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1580.0 > 852
# coord[2]>q[2]:1844.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  6
# Coord: [ 173.  166.  420. 1017.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:173.0 > 50
# coord[2]>q[2]:420.0 < 838
# Coord: [ 173.  166.  420. 1017.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:173.0 > 852
# coord[2]>q[2]:420.0 < 1430
# Coord: [569. 143. 873. 995.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:569.0 > 50
# coord[2]>q[2]:873.0 < 838
# Coord: [569. 143. 873. 995.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:569.0 > 852
# coord[2]>q[2]:873.0 < 1430
# Coord: [ 794.   92. 1084.  961.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:794.0 > 50
# coord[2]>q[2]:1084.0 < 838
# Coord: [ 794.   92. 1084.  961.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:794.0 > 852
# coord[2]>q[2]:1084.0 < 1430
# Coord: [1480.  155. 1757. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1480.0 > 50
# coord[2]>q[2]:1757.0 < 838
# Coord: [1480.  155. 1757. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1480.0 > 852
# coord[2]>q[2]:1757.0 < 1430
# Coord: [374. 110. 663. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:374.0 > 50
# coord[2]>q[2]:663.0 < 838
# Coord: [374. 110. 663. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:374.0 > 852
# coord[2]>q[2]:663.0 < 1430
# Coord: [1228.  158. 1521. 1031.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1228.0 > 50
# coord[2]>q[2]:1521.0 < 838
# Coord: [1228.  158. 1521. 1031.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1228.0 > 852
# coord[2]>q[2]:1521.0 < 1430
# Total People in frame = 6
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 173.  167.  420. 1018.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:173.0 > 50
# coord[2]>q[2]:420.0 < 838
# Coord: [ 173.  167.  420. 1018.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:173.0 > 852
# coord[2]>q[2]:420.0 < 1430
# Coord: [ 794.   97. 1082.  962.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:794.0 > 50
# coord[2]>q[2]:1082.0 < 838
# Coord: [ 794.   97. 1082.  962.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:794.0 > 852
# coord[2]>q[2]:1082.0 < 1430
# Coord: [572. 142. 872. 999.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:572.0 > 50
# coord[2]>q[2]:872.0 < 838
# Coord: [572. 142. 872. 999.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:572.0 > 852
# coord[2]>q[2]:872.0 < 1430
# Coord: [1466.  160. 1748. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1466.0 > 50
# coord[2]>q[2]:1748.0 < 838
# Coord: [1466.  160. 1748. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1466.0 > 852
# coord[2]>q[2]:1748.0 < 1430
# Coord: [371. 108. 658. 984.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:371.0 > 50
# coord[2]>q[2]:658.0 < 838
# Coord: [371. 108. 658. 984.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:371.0 > 852
# coord[2]>q[2]:658.0 < 1430
# Coord: [1217.  170. 1512. 1047.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1217.0 > 50
# coord[2]>q[2]:1512.0 < 838
# Coord: [1217.  170. 1512. 1047.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1217.0 > 852
# coord[2]>q[2]:1512.0 < 1430
# Coord: [1585.  131. 1845.  992.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1585.0 > 50
# coord[2]>q[2]:1845.0 < 838
# Coord: [1585.  131. 1845.  992.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1585.0 > 852
# coord[2]>q[2]:1845.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 171.  165.  419. 1016.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:171.0 > 50
# coord[2]>q[2]:419.0 < 838
# Coord: [ 171.  165.  419. 1016.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:171.0 > 852
# coord[2]>q[2]:419.0 < 1430
# Coord: [ 572.  150.  872. 1000.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:572.0 > 50
# coord[2]>q[2]:872.0 < 838
# Coord: [ 572.  150.  872. 1000.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:572.0 > 852
# coord[2]>q[2]:872.0 < 1430
# Coord: [ 792.   99. 1073.  954.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:792.0 > 50
# coord[2]>q[2]:1073.0 < 838
# Coord: [ 792.   99. 1073.  954.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:792.0 > 852
# coord[2]>q[2]:1073.0 < 1430
# Coord: [1457.  159. 1743. 1032.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1457.0 > 50
# coord[2]>q[2]:1743.0 < 838
# Coord: [1457.  159. 1743. 1032.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1457.0 > 852
# coord[2]>q[2]:1743.0 < 1430
# Coord: [363. 126. 648. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:363.0 > 50
# coord[2]>q[2]:648.0 < 838
# Coord: [363. 126. 648. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:363.0 > 852
# coord[2]>q[2]:648.0 < 1430
# Coord: [1119.  166. 1514. 1013.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1119.0 > 50
# coord[2]>q[2]:1514.0 < 838
# Coord: [1119.  166. 1514. 1013.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1119.0 > 852
# coord[2]>q[2]:1514.0 < 1430
# Coord: [1594.  135. 1845.  990.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1594.0 > 50
# coord[2]>q[2]:1845.0 < 838
# Coord: [1594.  135. 1845.  990.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1594.0 > 852
# coord[2]>q[2]:1845.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 172.  167.  417. 1019.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:172.0 > 50
# coord[2]>q[2]:417.0 < 838
# Coord: [ 172.  167.  417. 1019.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:172.0 > 852
# coord[2]>q[2]:417.0 < 1430
# Coord: [ 573.  147.  872. 1001.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:573.0 > 50
# coord[2]>q[2]:872.0 < 838
# Coord: [ 573.  147.  872. 1001.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:573.0 > 852
# coord[2]>q[2]:872.0 < 1430
# Coord: [ 789.  104. 1074.  956.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:789.0 > 50
# coord[2]>q[2]:1074.0 < 838
# Coord: [ 789.  104. 1074.  956.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:789.0 > 852
# coord[2]>q[2]:1074.0 < 1430
# Coord: [1461.  153. 1746. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1461.0 > 50
# coord[2]>q[2]:1746.0 < 838
# Coord: [1461.  153. 1746. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1461.0 > 852
# coord[2]>q[2]:1746.0 < 1430
# Coord: [360. 125. 646. 987.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:360.0 > 50
# coord[2]>q[2]:646.0 < 838
# Coord: [360. 125. 646. 987.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:360.0 > 852
# coord[2]>q[2]:646.0 < 1430
# Coord: [1093.  159. 1503. 1026.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1093.0 > 50
# coord[2]>q[2]:1503.0 < 838
# Coord: [1093.  159. 1503. 1026.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1093.0 > 852
# coord[2]>q[2]:1503.0 < 1430
# Coord: [1579.  121. 1843.  975.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1579.0 > 50
# coord[2]>q[2]:1843.0 < 838
# Coord: [1579.  121. 1843.  975.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1579.0 > 852
# coord[2]>q[2]:1843.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 170.  168.  414. 1021.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:170.0 > 50
# coord[2]>q[2]:414.0 < 838
# Coord: [ 170.  168.  414. 1021.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:170.0 > 852
# coord[2]>q[2]:414.0 < 1430
# Coord: [ 573.  148.  871. 1001.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:573.0 > 50
# coord[2]>q[2]:871.0 < 838
# Coord: [ 573.  148.  871. 1001.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:573.0 > 852
# coord[2]>q[2]:871.0 < 1430
# Coord: [ 785.  103. 1072.  959.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:785.0 > 50
# coord[2]>q[2]:1072.0 < 838
# Coord: [ 785.  103. 1072.  959.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:785.0 > 852
# coord[2]>q[2]:1072.0 < 1430
# Coord: [1461.  150. 1742. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1461.0 > 50
# coord[2]>q[2]:1742.0 < 838
# Coord: [1461.  150. 1742. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1461.0 > 852
# coord[2]>q[2]:1742.0 < 1430
# Coord: [1055.  162. 1502. 1020.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1055.0 > 50
# coord[2]>q[2]:1502.0 < 838
# Coord: [1055.  162. 1502. 1020.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1055.0 > 852
# coord[2]>q[2]:1502.0 < 1430
# Coord: [358. 127. 643. 987.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:358.0 > 50
# coord[2]>q[2]:643.0 < 838
# Coord: [358. 127. 643. 987.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:358.0 > 852
# coord[2]>q[2]:643.0 < 1430
# Coord: [1600.  132. 1837.  965.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1600.0 > 50
# coord[2]>q[2]:1837.0 < 838
# Coord: [1600.  132. 1837.  965.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1600.0 > 852
# coord[2]>q[2]:1837.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 172.  168.  414. 1019.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:172.0 > 50
# coord[2]>q[2]:414.0 < 838
# Coord: [ 172.  168.  414. 1019.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:172.0 > 852
# coord[2]>q[2]:414.0 < 1430
# Coord: [ 573.  150.  870. 1000.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:573.0 > 50
# coord[2]>q[2]:870.0 < 838
# Coord: [ 573.  150.  870. 1000.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:573.0 > 852
# coord[2]>q[2]:870.0 < 1430
# Coord: [ 778.  108. 1061.  965.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:778.0 > 50
# coord[2]>q[2]:1061.0 < 838
# Coord: [ 778.  108. 1061.  965.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:778.0 > 852
# coord[2]>q[2]:1061.0 < 1430
# Coord: [1452.  162. 1744. 1032.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1452.0 > 50
# coord[2]>q[2]:1744.0 < 838
# Coord: [1452.  162. 1744. 1032.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1452.0 > 852
# coord[2]>q[2]:1744.0 < 1430
# Coord: [359. 125. 643. 985.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:359.0 > 50
# coord[2]>q[2]:643.0 < 838
# Coord: [359. 125. 643. 985.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:359.0 > 852
# coord[2]>q[2]:643.0 < 1430
# Coord: [1042.  168. 1484. 1057.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1042.0 > 50
# coord[2]>q[2]:1484.0 < 838
# Coord: [1042.  168. 1484. 1057.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1042.0 > 852
# coord[2]>q[2]:1484.0 < 1430
# Coord: [1595.  139. 1830.  960.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1595.0 > 50
# coord[2]>q[2]:1830.0 < 838
# Coord: [1595.  139. 1830.  960.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1595.0 > 852
# coord[2]>q[2]:1830.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 173.  168.  415. 1017.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:173.0 > 50
# coord[2]>q[2]:415.0 < 838
# Coord: [ 173.  168.  415. 1017.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:173.0 > 852
# coord[2]>q[2]:415.0 < 1430
# Coord: [574. 138. 871. 999.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:871.0 < 838
# Coord: [574. 138. 871. 999.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:871.0 < 1430
# Coord: [ 779.  110. 1050.  963.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:779.0 > 50
# coord[2]>q[2]:1050.0 < 838
# Coord: [ 779.  110. 1050.  963.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:779.0 > 852
# coord[2]>q[2]:1050.0 < 1430
# Coord: [1447.  146. 1749. 1010.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1447.0 > 50
# coord[2]>q[2]:1749.0 < 838
# Coord: [1447.  146. 1749. 1010.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1447.0 > 852
# coord[2]>q[2]:1749.0 < 1430
# Coord: [360. 118. 650. 986.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:360.0 > 50
# coord[2]>q[2]:650.0 < 838
# Coord: [360. 118. 650. 986.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:360.0 > 852
# coord[2]>q[2]:650.0 < 1430
# Coord: [1207.  164. 1476. 1016.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1207.0 > 50
# coord[2]>q[2]:1476.0 < 838
# Coord: [1207.  164. 1476. 1016.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1207.0 > 852
# coord[2]>q[2]:1476.0 < 1430
# Coord: [1589.  132. 1831.  958.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1589.0 > 50
# coord[2]>q[2]:1831.0 < 838
# Coord: [1589.  132. 1831.  958.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1589.0 > 852
# coord[2]>q[2]:1831.0 < 1430
# Coord: [1067.  175. 1379. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1067.0 > 50
# coord[2]>q[2]:1379.0 < 838
# Coord: [1067.  175. 1379. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1067.0 > 852
# coord[2]>q[2]:1379.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 171.  170.  412. 1018.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:171.0 > 50
# coord[2]>q[2]:412.0 < 838
# Coord: [ 171.  170.  412. 1018.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:171.0 > 852
# coord[2]>q[2]:412.0 < 1430
# Coord: [ 576.  139.  872. 1022.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:576.0 > 50
# coord[2]>q[2]:872.0 < 838
# Coord: [ 576.  139.  872. 1022.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:576.0 > 852
# coord[2]>q[2]:872.0 < 1430
# Coord: [ 776.  100. 1048.  957.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:776.0 > 50
# coord[2]>q[2]:1048.0 < 838
# Coord: [ 776.  100. 1048.  957.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:776.0 > 852
# coord[2]>q[2]:1048.0 < 1430
# Coord: [357. 120. 646. 987.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:357.0 > 50
# coord[2]>q[2]:646.0 < 838
# Coord: [357. 120. 646. 987.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:357.0 > 852
# coord[2]>q[2]:646.0 < 1430
# Coord: [1442.  153. 1748. 1013.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1442.0 > 50
# coord[2]>q[2]:1748.0 < 838
# Coord: [1442.  153. 1748. 1013.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1442.0 > 852
# coord[2]>q[2]:1748.0 < 1430
# Coord: [1210.  157. 1469. 1009.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1210.0 > 50
# coord[2]>q[2]:1469.0 < 838
# Coord: [1210.  157. 1469. 1009.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1210.0 > 852
# coord[2]>q[2]:1469.0 < 1430
# Coord: [1052.  174. 1367. 1012.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1052.0 > 50
# coord[2]>q[2]:1367.0 < 838
# Coord: [1052.  174. 1367. 1012.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1052.0 > 852
# coord[2]>q[2]:1367.0 < 1430
# Coord: [1590.  135. 1824.  962.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1590.0 > 50
# coord[2]>q[2]:1824.0 < 838
# Coord: [1590.  135. 1824.  962.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1590.0 > 852
# coord[2]>q[2]:1824.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 170.  175.  412. 1016.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:170.0 > 50
# coord[2]>q[2]:412.0 < 838
# Coord: [ 170.  175.  412. 1016.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:170.0 > 852
# coord[2]>q[2]:412.0 < 1430
# Coord: [574. 135. 871. 996.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:871.0 < 838
# Coord: [574. 135. 871. 996.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:871.0 < 1430
# Coord: [1218.  163. 1476. 1031.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1218.0 > 50
# coord[2]>q[2]:1476.0 < 838
# Coord: [1218.  163. 1476. 1031.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1218.0 > 852
# coord[2]>q[2]:1476.0 < 1430
# Coord: [ 779.  112. 1046.  963.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:779.0 > 50
# coord[2]>q[2]:1046.0 < 838
# Coord: [ 779.  112. 1046.  963.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:779.0 > 852
# coord[2]>q[2]:1046.0 < 1430
# Coord: [1444.  148. 1748. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1444.0 > 50
# coord[2]>q[2]:1748.0 < 838
# Coord: [1444.  148. 1748. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1444.0 > 852
# coord[2]>q[2]:1748.0 < 1430
# Coord: [366. 101. 657. 986.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:366.0 > 50
# coord[2]>q[2]:657.0 < 838
# Coord: [366. 101. 657. 986.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:366.0 > 852
# coord[2]>q[2]:657.0 < 1430
# Coord: [1040.  175. 1342. 1017.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1040.0 > 50
# coord[2]>q[2]:1342.0 < 838
# Coord: [1040.  175. 1342. 1017.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1040.0 > 852
# coord[2]>q[2]:1342.0 < 1430
# Coord: [1597.  133. 1830.  965.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1597.0 > 50
# coord[2]>q[2]:1830.0 < 838
# Coord: [1597.  133. 1830.  965.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1597.0 > 852
# coord[2]>q[2]:1830.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 167.  177.  407. 1016.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:167.0 > 50
# coord[2]>q[2]:407.0 < 838
# Coord: [ 167.  177.  407. 1016.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:167.0 > 852
# coord[2]>q[2]:407.0 < 1430
# Coord: [1188.  153. 1467. 1022.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1188.0 > 50
# coord[2]>q[2]:1467.0 < 838
# Coord: [1188.  153. 1467. 1022.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1188.0 > 852
# coord[2]>q[2]:1467.0 < 1430
# Coord: [574. 142. 869. 999.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:869.0 < 838
# Coord: [574. 142. 869. 999.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:869.0 < 1430
# Coord: [1444.  152. 1740. 1010.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1444.0 > 50
# coord[2]>q[2]:1740.0 < 838
# Coord: [1444.  152. 1740. 1010.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1444.0 > 852
# coord[2]>q[2]:1740.0 < 1430
# Coord: [367. 101. 656. 989.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:367.0 > 50
# coord[2]>q[2]:656.0 < 838
# Coord: [367. 101. 656. 989.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:367.0 > 852
# coord[2]>q[2]:656.0 < 1430
# Coord: [ 779.  107. 1040.  965.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:779.0 > 50
# coord[2]>q[2]:1040.0 < 838
# Coord: [ 779.  107. 1040.  965.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:779.0 > 852
# coord[2]>q[2]:1040.0 < 1430
# Coord: [1019.  179. 1306. 1028.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1019.0 > 50
# coord[2]>q[2]:1306.0 < 838
# Coord: [1019.  179. 1306. 1028.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1019.0 > 852
# coord[2]>q[2]:1306.0 < 1430
# Coord: [1600.  122. 1826.  952.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1600.0 > 50
# coord[2]>q[2]:1826.0 < 838
# Coord: [1600.  122. 1826.  952.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1600.0 > 852
# coord[2]>q[2]:1826.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 166.  173.  403. 1012.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:166.0 > 50
# coord[2]>q[2]:403.0 < 838
# Coord: [ 166.  173.  403. 1012.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:166.0 > 852
# coord[2]>q[2]:403.0 < 1430
# Coord: [1201.  149. 1460. 1006.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1201.0 > 50
# coord[2]>q[2]:1460.0 < 838
# Coord: [1201.  149. 1460. 1006.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1201.0 > 852
# coord[2]>q[2]:1460.0 < 1430
# Coord: [ 575.  148.  867. 1003.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:575.0 > 50
# coord[2]>q[2]:867.0 < 838
# Coord: [ 575.  148.  867. 1003.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:575.0 > 852
# coord[2]>q[2]:867.0 < 1430
# Coord: [1450.  148. 1745. 1005.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1450.0 > 50
# coord[2]>q[2]:1745.0 < 838
# Coord: [1450.  148. 1745. 1005.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1450.0 > 852
# coord[2]>q[2]:1745.0 < 1430
# Coord: [1013.  180. 1278. 1003.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1013.0 > 50
# coord[2]>q[2]:1278.0 < 838
# Coord: [1013.  180. 1278. 1003.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1013.0 > 852
# coord[2]>q[2]:1278.0 < 1430
# Coord: [ 780.  109. 1048.  968.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:780.0 > 50
# coord[2]>q[2]:1048.0 < 838
# Coord: [ 780.  109. 1048.  968.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:780.0 > 852
# coord[2]>q[2]:1048.0 < 1430
# Coord: [364. 104. 657. 987.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:364.0 > 50
# coord[2]>q[2]:657.0 < 838
# Coord: [364. 104. 657. 987.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:364.0 > 852
# coord[2]>q[2]:657.0 < 1430
# Coord: [1598.  110. 1821.  943.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1598.0 > 50
# coord[2]>q[2]:1821.0 < 838
# Coord: [1598.  110. 1821.  943.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1598.0 > 852
# coord[2]>q[2]:1821.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 164.  173.  404. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:164.0 > 50
# coord[2]>q[2]:404.0 < 838
# Coord: [ 164.  173.  404. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:164.0 > 852
# coord[2]>q[2]:404.0 < 1430
# Coord: [1209.  152. 1463. 1043.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1209.0 > 50
# coord[2]>q[2]:1463.0 < 838
# Coord: [1209.  152. 1463. 1043.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1209.0 > 852
# coord[2]>q[2]:1463.0 < 1430
# Coord: [ 576.  150.  869. 1005.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:576.0 > 50
# coord[2]>q[2]:869.0 < 838
# Coord: [ 576.  150.  869. 1005.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:576.0 > 852
# coord[2]>q[2]:869.0 < 1430
# Coord: [1443.  156. 1738. 1011.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1443.0 > 50
# coord[2]>q[2]:1738.0 < 838
# Coord: [1443.  156. 1738. 1011.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1443.0 > 852
# coord[2]>q[2]:1738.0 < 1430
# Coord: [1005.  173. 1248. 1027.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1005.0 > 50
# coord[2]>q[2]:1248.0 < 838
# Coord: [1005.  173. 1248. 1027.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1005.0 > 852
# coord[2]>q[2]:1248.0 < 1430
# Coord: [ 777.  107. 1044.  964.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:777.0 > 50
# coord[2]>q[2]:1044.0 < 838
# Coord: [ 777.  107. 1044.  964.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:777.0 > 852
# coord[2]>q[2]:1044.0 < 1430
# Coord: [358. 114. 652. 989.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:358.0 > 50
# coord[2]>q[2]:652.0 < 838
# Coord: [358. 114. 652. 989.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:358.0 > 852
# coord[2]>q[2]:652.0 < 1430
# Coord: [1597.  127. 1834.  958.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1597.0 > 50
# coord[2]>q[2]:1834.0 < 838
# Coord: [1597.  127. 1834.  958.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1597.0 > 852
# coord[2]>q[2]:1834.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1211.  153. 1465. 1048.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1211.0 > 50
# coord[2]>q[2]:1465.0 < 838
# Coord: [1211.  153. 1465. 1048.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1211.0 > 852
# coord[2]>q[2]:1465.0 < 1430
# Coord: [ 161.  172.  401. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:161.0 > 50
# coord[2]>q[2]:401.0 < 838
# Coord: [ 161.  172.  401. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:161.0 > 852
# coord[2]>q[2]:401.0 < 1430
# Coord: [ 575.  155.  867. 1004.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:575.0 > 50
# coord[2]>q[2]:867.0 < 838
# Coord: [ 575.  155.  867. 1004.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:575.0 > 852
# coord[2]>q[2]:867.0 < 1430
# Coord: [ 999.  170. 1242. 1014.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:999.0 > 50
# coord[2]>q[2]:1242.0 < 838
# Coord: [ 999.  170. 1242. 1014.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:999.0 > 852
# coord[2]>q[2]:1242.0 < 1430
# Coord: [1445.  152. 1739. 1009.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1445.0 > 50
# coord[2]>q[2]:1739.0 < 838
# Coord: [1445.  152. 1739. 1009.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1445.0 > 852
# coord[2]>q[2]:1739.0 < 1430
# Coord: [358. 116. 647. 988.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:358.0 > 50
# coord[2]>q[2]:647.0 < 838
# Coord: [358. 116. 647. 988.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:358.0 > 852
# coord[2]>q[2]:647.0 < 1430
# Coord: [ 775.  100. 1045.  968.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:775.0 > 50
# coord[2]>q[2]:1045.0 < 838
# Coord: [ 775.  100. 1045.  968.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:775.0 > 852
# coord[2]>q[2]:1045.0 < 1430
# Coord: [1608.  139. 1834.  952.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1608.0 > 50
# coord[2]>q[2]:1834.0 < 838
# Coord: [1608.  139. 1834.  952.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1608.0 > 852
# coord[2]>q[2]:1834.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1215.  154. 1466. 1053.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1215.0 > 50
# coord[2]>q[2]:1466.0 < 838
# Coord: [1215.  154. 1466. 1053.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1215.0 > 852
# coord[2]>q[2]:1466.0 < 1430
# Coord: [ 159.  173.  407. 1035.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:159.0 > 50
# coord[2]>q[2]:407.0 < 838
# Coord: [ 159.  173.  407. 1035.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:159.0 > 852
# coord[2]>q[2]:407.0 < 1430
# Coord: [ 574.  155.  866. 1006.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:866.0 < 838
# Coord: [ 574.  155.  866. 1006.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:866.0 < 1430
# Coord: [ 983.  167. 1217. 1008.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:983.0 > 50
# coord[2]>q[2]:1217.0 < 838
# Coord: [ 983.  167. 1217. 1008.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:983.0 > 852
# coord[2]>q[2]:1217.0 < 1430
# Coord: [1442.  162. 1740. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1442.0 > 50
# coord[2]>q[2]:1740.0 < 838
# Coord: [1442.  162. 1740. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1442.0 > 852
# coord[2]>q[2]:1740.0 < 1430
# Coord: [ 776.   95. 1027.  970.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:776.0 > 50
# coord[2]>q[2]:1027.0 < 838
# Coord: [ 776.   95. 1027.  970.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:776.0 > 852
# coord[2]>q[2]:1027.0 < 1430
# Coord: [358. 121. 651. 981.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:358.0 > 50
# coord[2]>q[2]:651.0 < 838
# Coord: [358. 121. 651. 981.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:358.0 > 852
# coord[2]>q[2]:651.0 < 1430
# Coord: [1611.  158. 1827.  961.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1611.0 > 50
# coord[2]>q[2]:1827.0 < 838
# Coord: [1611.  158. 1827.  961.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1611.0 > 852
# coord[2]>q[2]:1827.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1215.  149. 1466. 1050.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1215.0 > 50
# coord[2]>q[2]:1466.0 < 838
# Coord: [1215.  149. 1466. 1050.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1215.0 > 852
# coord[2]>q[2]:1466.0 < 1430
# Coord: [ 155.  171.  406. 1037.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:155.0 > 50
# coord[2]>q[2]:406.0 < 838
# Coord: [ 155.  171.  406. 1037.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:155.0 > 852
# coord[2]>q[2]:406.0 < 1430
# Coord: [ 574.  148.  874. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:874.0 < 838
# Coord: [ 574.  148.  874. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:874.0 < 1430
# Coord: [ 954.  149. 1186. 1001.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:954.0 > 50
# coord[2]>q[2]:1186.0 < 838
# Coord: [ 954.  149. 1186. 1001.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:954.0 > 852
# coord[2]>q[2]:1186.0 < 1430
# Coord: [1444.  159. 1744. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1444.0 > 50
# coord[2]>q[2]:1744.0 < 838
# Coord: [1444.  159. 1744. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1444.0 > 852
# coord[2]>q[2]:1744.0 < 1430
# Coord: [ 766.   96. 1003.  960.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:766.0 > 50
# coord[2]>q[2]:1003.0 < 838
# Coord: [ 766.   96. 1003.  960.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:766.0 > 852
# coord[2]>q[2]:1003.0 < 1430
# Coord: [355. 117. 652. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:355.0 > 50
# coord[2]>q[2]:652.0 < 838
# Coord: [355. 117. 652. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:355.0 > 852
# coord[2]>q[2]:652.0 < 1430
# Coord: [1596.  130. 1840.  965.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1596.0 > 50
# coord[2]>q[2]:1840.0 < 838
# Coord: [1596.  130. 1840.  965.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1596.0 > 852
# coord[2]>q[2]:1840.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1215.  148. 1465. 1048.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1215.0 > 50
# coord[2]>q[2]:1465.0 < 838
# Coord: [1215.  148. 1465. 1048.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1215.0 > 852
# coord[2]>q[2]:1465.0 < 1430
# Coord: [ 155.  171.  407. 1037.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:155.0 > 50
# coord[2]>q[2]:407.0 < 838
# Coord: [ 155.  171.  407. 1037.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:155.0 > 852
# coord[2]>q[2]:407.0 < 1430
# Coord: [ 924.  156. 1178. 1033.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:924.0 > 50
# coord[2]>q[2]:1178.0 < 838
# Coord: [ 924.  156. 1178. 1033.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:924.0 > 852
# coord[2]>q[2]:1178.0 < 1430
# Coord: [571. 147. 877. 998.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:571.0 > 50
# coord[2]>q[2]:877.0 < 838
# Coord: [571. 147. 877. 998.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:571.0 > 852
# coord[2]>q[2]:877.0 < 1430
# Coord: [1443.  161. 1745. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1443.0 > 50
# coord[2]>q[2]:1745.0 < 838
# Coord: [1443.  161. 1745. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1443.0 > 852
# coord[2]>q[2]:1745.0 < 1430
# Coord: [ 351.   93.  632. 1008.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:351.0 > 50
# coord[2]>q[2]:632.0 < 838
# Coord: [ 351.   93.  632. 1008.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:351.0 > 852
# coord[2]>q[2]:632.0 < 1430
# Coord: [765.  98. 992. 966.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:765.0 > 50
# coord[2]>q[2]:992.0 < 838
# Coord: [765.  98. 992. 966.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:765.0 > 852
# coord[2]>q[2]:992.0 < 1430
# Coord: [1592.  127. 1840.  960.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1592.0 > 50
# coord[2]>q[2]:1840.0 < 838
# Coord: [1592.  127. 1840.  960.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1592.0 > 852
# coord[2]>q[2]:1840.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1213.  153. 1464. 1044.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1213.0 > 50
# coord[2]>q[2]:1464.0 < 838
# Coord: [1213.  153. 1464. 1044.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1213.0 > 852
# coord[2]>q[2]:1464.0 < 1430
# Coord: [ 153.  170.  403. 1039.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:153.0 > 50
# coord[2]>q[2]:403.0 < 838
# Coord: [ 153.  170.  403. 1039.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:153.0 > 852
# coord[2]>q[2]:403.0 < 1430
# Coord: [ 906.  168. 1161.  993.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:906.0 > 50
# coord[2]>q[2]:1161.0 < 838
# Coord: [ 906.  168. 1161.  993.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:906.0 > 852
# coord[2]>q[2]:1161.0 < 1430
# Coord: [ 571.  137.  885. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:571.0 > 50
# coord[2]>q[2]:885.0 < 838
# Coord: [ 571.  137.  885. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:571.0 > 852
# coord[2]>q[2]:885.0 < 1430
# Coord: [1445.  162. 1743. 1032.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1445.0 > 50
# coord[2]>q[2]:1743.0 < 838
# Coord: [1445.  162. 1743. 1032.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1445.0 > 852
# coord[2]>q[2]:1743.0 < 1430
# Coord: [ 346.   99.  633. 1008.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:346.0 > 50
# coord[2]>q[2]:633.0 < 838
# Coord: [ 346.   99.  633. 1008.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:346.0 > 852
# coord[2]>q[2]:633.0 < 1430
# Coord: [772. 107. 981. 906.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:772.0 > 50
# coord[2]>q[2]:981.0 < 838
# Coord: [772. 107. 981. 906.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:772.0 > 852
# coord[2]>q[2]:981.0 < 1430
# Coord: [1597.  139. 1828.  956.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1597.0 > 50
# coord[2]>q[2]:1828.0 < 838
# Coord: [1597.  139. 1828.  956.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1597.0 > 852
# coord[2]>q[2]:1828.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [1212.  147. 1463. 1046.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1212.0 > 50
# coord[2]>q[2]:1463.0 < 838
# Coord: [1212.  147. 1463. 1046.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1212.0 > 852
# coord[2]>q[2]:1463.0 < 1430
# Coord: [ 152.  169.  403. 1044.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:152.0 > 50
# coord[2]>q[2]:403.0 < 838
# Coord: [ 152.  169.  403. 1044.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:152.0 > 852
# coord[2]>q[2]:403.0 < 1430
# Coord: [1450.  152. 1740. 1012.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1450.0 > 50
# coord[2]>q[2]:1740.0 < 838
# Coord: [1450.  152. 1740. 1012.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1450.0 > 852
# coord[2]>q[2]:1740.0 < 1430
# Coord: [ 574.  143.  884. 1025.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:574.0 > 50
# coord[2]>q[2]:884.0 < 838
# Coord: [ 574.  143.  884. 1025.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:574.0 > 852
# coord[2]>q[2]:884.0 < 1430
# Coord: [ 866.  144. 1143. 1006.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:866.0 > 50
# coord[2]>q[2]:1143.0 < 838
# Coord: [ 866.  144. 1143. 1006.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:866.0 > 852
# coord[2]>q[2]:1143.0 < 1430
# Coord: [ 349.   97.  635. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:349.0 > 50
# coord[2]>q[2]:635.0 < 838
# Coord: [ 349.   97.  635. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:349.0 > 852
# coord[2]>q[2]:635.0 < 1430
# Coord: [765. 113. 998. 923.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:765.0 > 50
# coord[2]>q[2]:998.0 < 838
# Coord: [765. 113. 998. 923.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:765.0 > 852
# coord[2]>q[2]:998.0 < 1430
# Coord: [1592.  135. 1820.  956.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1592.0 > 50
# coord[2]>q[2]:1820.0 < 838
# Coord: [1592.  135. 1820.  956.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1592.0 > 852
# coord[2]>q[2]:1820.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [1214.  148. 1463. 1052.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1214.0 > 50
# coord[2]>q[2]:1463.0 < 838
# Coord: [1214.  148. 1463. 1052.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1214.0 > 852
# coord[2]>q[2]:1463.0 < 1430
# Coord: [ 150.  167.  407. 1044.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:150.0 > 50
# coord[2]>q[2]:407.0 < 838
# Coord: [ 150.  167.  407. 1044.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:150.0 > 852
# coord[2]>q[2]:407.0 < 1430
# Coord: [ 571.  152.  869. 1018.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:571.0 > 50
# coord[2]>q[2]:869.0 < 838
# Coord: [ 571.  152.  869. 1018.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:571.0 > 852
# coord[2]>q[2]:869.0 < 1430
# Coord: [1447.  140. 1741. 1028.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1447.0 > 50
# coord[2]>q[2]:1741.0 < 838
# Coord: [1447.  140. 1741. 1028.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1447.0 > 852
# coord[2]>q[2]:1741.0 < 1430
# Coord: [ 789.  145. 1134. 1007.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:789.0 > 50
# coord[2]>q[2]:1134.0 < 838
# Coord: [ 789.  145. 1134. 1007.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:789.0 > 852
# coord[2]>q[2]:1134.0 < 1430
# Coord: [355. 123. 657. 964.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:355.0 > 50
# coord[2]>q[2]:657.0 < 838
# Coord: [355. 123. 657. 964.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:355.0 > 852
# coord[2]>q[2]:657.0 < 1430
# Coord: [1593.  125. 1816.  974.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1593.0 > 50
# coord[2]>q[2]:1816.0 < 838
# Coord: [1593.  125. 1816.  974.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1593.0 > 852
# coord[2]>q[2]:1816.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 145.  166.  398. 1039.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:145.0 > 50
# coord[2]>q[2]:398.0 < 838
# Coord: [ 145.  166.  398. 1039.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:145.0 > 852
# coord[2]>q[2]:398.0 < 1430
# Coord: [1216.  151. 1464. 1046.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1216.0 > 50
# coord[2]>q[2]:1464.0 < 838
# Coord: [1216.  151. 1464. 1046.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1216.0 > 852
# coord[2]>q[2]:1464.0 < 1430
# Coord: [569. 150. 863. 997.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:569.0 > 50
# coord[2]>q[2]:863.0 < 838
# Coord: [569. 150. 863. 997.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:569.0 > 852
# coord[2]>q[2]:863.0 < 1430
# Coord: [ 787.  174. 1128. 1015.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:787.0 > 50
# coord[2]>q[2]:1128.0 < 838
# Coord: [ 787.  174. 1128. 1015.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:787.0 > 852
# coord[2]>q[2]:1128.0 < 1430
# Coord: [1445.  154. 1739. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1445.0 > 50
# coord[2]>q[2]:1739.0 < 838
# Coord: [1445.  154. 1739. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1445.0 > 852
# coord[2]>q[2]:1739.0 < 1430
# Coord: [361. 100. 661. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:361.0 > 50
# coord[2]>q[2]:661.0 < 838
# Coord: [361. 100. 661. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:361.0 > 852
# coord[2]>q[2]:661.0 < 1430
# Coord: [1595.  137. 1819.  972.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1595.0 > 50
# coord[2]>q[2]:1819.0 < 838
# Coord: [1595.  137. 1819.  972.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1595.0 > 852
# coord[2]>q[2]:1819.0 < 1430
# Coord: [1410.  126. 1568.  676.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1410.0 > 50
# coord[2]>q[2]:1568.0 < 838
# Coord: [1410.  126. 1568.  676.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1410.0 > 852
# coord[2]>q[2]:1568.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [ 149.  165.  402. 1038.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:149.0 > 50
# coord[2]>q[2]:402.0 < 838
# Coord: [ 149.  165.  402. 1038.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:149.0 > 852
# coord[2]>q[2]:402.0 < 1430
# Coord: [1214.  149. 1461. 1049.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1214.0 > 50
# coord[2]>q[2]:1461.0 < 838
# Coord: [1214.  149. 1461. 1049.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1214.0 > 852
# coord[2]>q[2]:1461.0 < 1430
# Coord: [569. 160. 864. 994.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:569.0 > 50
# coord[2]>q[2]:864.0 < 838
# Coord: [569. 160. 864. 994.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:569.0 > 852
# coord[2]>q[2]:864.0 < 1430
# Coord: [ 738.  167. 1127. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:738.0 > 50
# coord[2]>q[2]:1127.0 < 838
# Coord: [ 738.  167. 1127. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:738.0 > 852
# coord[2]>q[2]:1127.0 < 1430
# Coord: [1445.  146. 1747. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1445.0 > 50
# coord[2]>q[2]:1747.0 < 838
# Coord: [1445.  146. 1747. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1445.0 > 852
# coord[2]>q[2]:1747.0 < 1430
# Coord: [364. 103. 661. 981.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:364.0 > 50
# coord[2]>q[2]:661.0 < 838
# Coord: [364. 103. 661. 981.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:364.0 > 852
# coord[2]>q[2]:661.0 < 1430
# Coord: [1584.  124. 1816.  976.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1584.0 > 50
# coord[2]>q[2]:1816.0 < 838
# Coord: [1584.  124. 1816.  976.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1584.0 > 852
# coord[2]>q[2]:1816.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  8
# Coord: [ 144.  164.  400. 1033.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:144.0 > 50
# coord[2]>q[2]:400.0 < 838
# Coord: [ 144.  164.  400. 1033.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:144.0 > 852
# coord[2]>q[2]:400.0 < 1430
# Coord: [ 568.  155.  857. 1004.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:568.0 > 50
# coord[2]>q[2]:857.0 < 838
# Coord: [ 568.  155.  857. 1004.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:568.0 > 852
# coord[2]>q[2]:857.0 < 1430
# Coord: [1215.  140. 1460. 1056.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1215.0 > 50
# coord[2]>q[2]:1460.0 < 838
# Coord: [1215.  140. 1460. 1056.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1215.0 > 852
# coord[2]>q[2]:1460.0 < 1430
# Coord: [ 738.  173. 1117. 1009.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:738.0 > 50
# coord[2]>q[2]:1117.0 < 838
# Coord: [ 738.  173. 1117. 1009.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:738.0 > 852
# coord[2]>q[2]:1117.0 < 1430
# Coord: [1444.  157. 1740. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1444.0 > 50
# coord[2]>q[2]:1740.0 < 838
# Coord: [1444.  157. 1740. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1444.0 > 852
# coord[2]>q[2]:1740.0 < 1430
# Coord: [368. 105. 660. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:368.0 > 50
# coord[2]>q[2]:660.0 < 838
# Coord: [368. 105. 660. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:368.0 > 852
# coord[2]>q[2]:660.0 < 1430
# Coord: [1594.  132. 1815.  971.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1594.0 > 50
# coord[2]>q[2]:1815.0 < 838
# Coord: [1594.  132. 1815.  971.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1594.0 > 852
# coord[2]>q[2]:1815.0 < 1430
# Coord: [1327.  131. 1536.  837.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1327.0 > 50
# coord[2]>q[2]:1536.0 < 838
# Coord: [1327.  131. 1536.  837.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1327.0 > 852
# coord[2]>q[2]:1536.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 142.  163.  393. 1032.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:142.0 > 50
# coord[2]>q[2]:393.0 < 838
# Coord: [ 142.  163.  393. 1032.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:142.0 > 852
# coord[2]>q[2]:393.0 < 1430
# Coord: [ 569.  152.  845. 1013.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:569.0 > 50
# coord[2]>q[2]:845.0 < 838
# Coord: [ 569.  152.  845. 1013.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:569.0 > 852
# coord[2]>q[2]:845.0 < 1430
# Coord: [1218.  141. 1462. 1063.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1218.0 > 50
# coord[2]>q[2]:1462.0 < 838
# Coord: [1218.  141. 1462. 1063.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1218.0 > 852
# coord[2]>q[2]:1462.0 < 1430
# Coord: [ 719.  197. 1120. 1021.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:719.0 > 50
# coord[2]>q[2]:1120.0 < 838
# Coord: [ 719.  197. 1120. 1021.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:719.0 > 852
# coord[2]>q[2]:1120.0 < 1430
# Coord: [1446.  139. 1738. 1029.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1446.0 > 50
# coord[2]>q[2]:1738.0 < 838
# Coord: [1446.  139. 1738. 1029.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1446.0 > 852
# coord[2]>q[2]:1738.0 < 1430
# Coord: [368. 103. 658. 982.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:368.0 > 50
# coord[2]>q[2]:658.0 < 838
# Coord: [368. 103. 658. 982.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:368.0 > 852
# coord[2]>q[2]:658.0 < 1430
# Coord: [1600.  117. 1818.  976.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1600.0 > 50
# coord[2]>q[2]:1818.0 < 838
# Coord: [1600.  117. 1818.  976.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1600.0 > 852
# coord[2]>q[2]:1818.0 < 1430
# Coord: [1317.  122. 1523.  857.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1317.0 > 50
# coord[2]>q[2]:1523.0 < 838
# Coord: [1317.  122. 1523.  857.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1317.0 > 852
# coord[2]>q[2]:1523.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 139.  167.  397. 1030.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:139.0 > 50
# coord[2]>q[2]:397.0 < 838
# Coord: [ 139.  167.  397. 1030.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:139.0 > 852
# coord[2]>q[2]:397.0 < 1430
# Coord: [1219.  151. 1460. 1063.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1219.0 > 50
# coord[2]>q[2]:1460.0 < 838
# Coord: [1219.  151. 1460. 1063.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1219.0 > 852
# coord[2]>q[2]:1460.0 < 1430
# Coord: [ 571.  156.  828. 1013.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:571.0 > 50
# coord[2]>q[2]:828.0 < 838
# Coord: [ 571.  156.  828. 1013.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:571.0 > 852
# coord[2]>q[2]:828.0 < 1430
# Coord: [1448.  150. 1736. 1017.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1448.0 > 50
# coord[2]>q[2]:1736.0 < 838
# Coord: [1448.  150. 1736. 1017.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1448.0 > 852
# coord[2]>q[2]:1736.0 < 1430
# Coord: [371. 102. 656. 985.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:371.0 > 50
# coord[2]>q[2]:656.0 < 838
# Coord: [371. 102. 656. 985.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:371.0 > 852
# coord[2]>q[2]:656.0 < 1430
# Coord: [ 699.  184. 1109. 1008.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:699.0 > 50
# coord[2]>q[2]:1109.0 < 838
# Coord: [ 699.  184. 1109. 1008.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:699.0 > 852
# coord[2]>q[2]:1109.0 < 1430
# Coord: [1597.  119. 1815.  951.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1597.0 > 50
# coord[2]>q[2]:1815.0 < 838
# Coord: [1597.  119. 1815.  951.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1597.0 > 852
# coord[2]>q[2]:1815.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 0}
# Queues len:  2
# Coords len:  7
# Coord: [ 134.  166.  396. 1024.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:134.0 > 50
# coord[2]>q[2]:396.0 < 838
# Coord: [ 134.  166.  396. 1024.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:134.0 > 852
# coord[2]>q[2]:396.0 < 1430
# Coord: [1218.  137. 1466. 1057.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1218.0 > 50
# coord[2]>q[2]:1466.0 < 838
# Coord: [1218.  137. 1466. 1057.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1218.0 > 852
# coord[2]>q[2]:1466.0 < 1430
# Coord: [ 570.  155.  821. 1005.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:570.0 > 50
# ...
# coord[0]>q[0]:954.0 > 852
# coord[2]>q[2]:1161.0 < 1430
# Coord: [167. 222. 335. 703.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:167.0 > 50
# coord[2]>q[2]:335.0 < 838
# Coord: [167. 222. 335. 703.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:167.0 > 852
# coord[2]>q[2]:335.0 < 1430
# Coord: [145. 152. 269. 623.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:145.0 > 50
# coord[2]>q[2]:269.0 < 838
# Coord: [145. 152. 269. 623.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:145.0 > 852
# coord[2]>q[2]:269.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [ 758.  117. 1013.  953.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:758.0 > 50
# coord[2]>q[2]:1013.0 < 838
# Coord: [ 758.  117. 1013.  953.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:758.0 > 852
# coord[2]>q[2]:1013.0 < 1430
# Coord: [1522.  135. 1800.  952.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1522.0 > 50
# coord[2]>q[2]:1800.0 < 838
# Coord: [1522.  135. 1800.  952.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1522.0 > 852
# coord[2]>q[2]:1800.0 < 1430
# Coord: [395. 111. 640. 955.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:395.0 > 50
# coord[2]>q[2]:640.0 < 838
# Coord: [395. 111. 640. 955.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:395.0 > 852
# coord[2]>q[2]:640.0 < 1430
# Coord: [1131.  114. 1437.  958.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1131.0 > 50
# coord[2]>q[2]:1437.0 < 838
# Coord: [1131.  114. 1437.  958.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1131.0 > 852
# coord[2]>q[2]:1437.0 < 1430
# Coord: [1338.   63. 1569.  910.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1338.0 > 50
# coord[2]>q[2]:1569.0 < 838
# Coord: [1338.   63. 1569.  910.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1338.0 > 852
# coord[2]>q[2]:1569.0 < 1430
# Coord: [ 950.  125. 1165.  920.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:950.0 > 50
# coord[2]>q[2]:1165.0 < 838
# Coord: [ 950.  125. 1165.  920.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:950.0 > 852
# coord[2]>q[2]:1165.0 < 1430
# Coord: [144. 154. 268. 622.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:144.0 > 50
# coord[2]>q[2]:268.0 < 838
# Coord: [144. 154. 268. 622.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:144.0 > 852
# coord[2]>q[2]:268.0 < 1430
# Coord: [1773.   80. 1921.  931.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1773.0 > 50
# coord[2]>q[2]:1921.0 < 838
# Coord: [1773.   80. 1921.  931.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1773.0 > 852
# coord[2]>q[2]:1921.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 760.  120. 1018.  947.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:760.0 > 50
# coord[2]>q[2]:1018.0 < 838
# Coord: [ 760.  120. 1018.  947.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:760.0 > 852
# coord[2]>q[2]:1018.0 < 1430
# Coord: [1521.  136. 1800.  953.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1521.0 > 50
# coord[2]>q[2]:1800.0 < 838
# Coord: [1521.  136. 1800.  953.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1521.0 > 852
# coord[2]>q[2]:1800.0 < 1430
# Coord: [400. 109. 647. 945.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:400.0 > 50
# coord[2]>q[2]:647.0 < 838
# Coord: [400. 109. 647. 945.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:400.0 > 852
# coord[2]>q[2]:647.0 < 1430
# Coord: [1133.  116. 1434.  962.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1133.0 > 50
# coord[2]>q[2]:1434.0 < 838
# Coord: [1133.  116. 1434.  962.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1133.0 > 852
# coord[2]>q[2]:1434.0 < 1430
# Coord: [1340.   63. 1574.  910.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1340.0 > 50
# coord[2]>q[2]:1574.0 < 838
# Coord: [1340.   63. 1574.  910.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1340.0 > 852
# coord[2]>q[2]:1574.0 < 1430
# Coord: [ 966.  133. 1167.  869.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:966.0 > 50
# coord[2]>q[2]:1167.0 < 838
# Coord: [ 966.  133. 1167.  869.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:966.0 > 852
# coord[2]>q[2]:1167.0 < 1430
# Coord: [145. 154. 264. 617.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:145.0 > 50
# coord[2]>q[2]:264.0 < 838
# Coord: [145. 154. 264. 617.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:145.0 > 852
# coord[2]>q[2]:264.0 < 1430
# Coord: [1769.   76. 1922.  948.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1769.0 > 50
# coord[2]>q[2]:1922.0 < 838
# Coord: [1769.   76. 1922.  948.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1769.0 > 852
# coord[2]>q[2]:1922.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 759.  119. 1028.  941.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:759.0 > 50
# coord[2]>q[2]:1028.0 < 838
# Coord: [ 759.  119. 1028.  941.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:759.0 > 852
# coord[2]>q[2]:1028.0 < 1430
# Coord: [1519.  134. 1798.  954.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1519.0 > 50
# coord[2]>q[2]:1798.0 < 838
# Coord: [1519.  134. 1798.  954.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1519.0 > 852
# coord[2]>q[2]:1798.0 < 1430
# Coord: [409. 119. 650. 957.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:409.0 > 50
# coord[2]>q[2]:650.0 < 838
# Coord: [409. 119. 650. 957.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:409.0 > 852
# coord[2]>q[2]:650.0 < 1430
# Coord: [1128.  120. 1444.  970.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1128.0 > 50
# coord[2]>q[2]:1444.0 < 838
# Coord: [1128.  120. 1444.  970.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1128.0 > 852
# coord[2]>q[2]:1444.0 < 1430
# Coord: [ 984.  130. 1180.  852.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:984.0 > 50
# coord[2]>q[2]:1180.0 < 838
# Coord: [ 984.  130. 1180.  852.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:984.0 > 852
# coord[2]>q[2]:1180.0 < 1430
# Coord: [1355.   66. 1580.  907.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1355.0 > 50
# coord[2]>q[2]:1580.0 < 838
# Coord: [1355.   66. 1580.  907.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1355.0 > 852
# coord[2]>q[2]:1580.0 < 1430
# Coord: [1766.   75. 1921.  955.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1766.0 > 50
# coord[2]>q[2]:1921.0 < 838
# Coord: [1766.   75. 1921.  955.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1766.0 > 852
# coord[2]>q[2]:1921.0 < 1430
# Coord: [144. 152. 264. 620.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:144.0 > 50
# coord[2]>q[2]:264.0 < 838
# Coord: [144. 152. 264. 620.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:144.0 > 852
# coord[2]>q[2]:264.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  8
# Coord: [ 760.  121. 1031.  942.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:760.0 > 50
# coord[2]>q[2]:1031.0 < 838
# Coord: [ 760.  121. 1031.  942.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:760.0 > 852
# coord[2]>q[2]:1031.0 < 1430
# Coord: [1518.  139. 1801.  946.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1518.0 > 50
# coord[2]>q[2]:1801.0 < 838
# Coord: [1518.  139. 1801.  946.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1518.0 > 852
# coord[2]>q[2]:1801.0 < 1430
# Coord: [418. 119. 655. 954.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:418.0 > 50
# coord[2]>q[2]:655.0 < 838
# Coord: [418. 119. 655. 954.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:418.0 > 852
# coord[2]>q[2]:655.0 < 1430
# Coord: [1130.  118. 1444.  970.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1130.0 > 50
# coord[2]>q[2]:1444.0 < 838
# Coord: [1130.  118. 1444.  970.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1130.0 > 852
# coord[2]>q[2]:1444.0 < 1430
# Coord: [1000.  131. 1185.  801.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1000.0 > 50
# coord[2]>q[2]:1185.0 < 838
# Coord: [1000.  131. 1185.  801.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1000.0 > 852
# coord[2]>q[2]:1185.0 < 1430
# Coord: [1360.   70. 1584.  901.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1360.0 > 50
# coord[2]>q[2]:1584.0 < 838
# Coord: [1360.   70. 1584.  901.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1360.0 > 852
# coord[2]>q[2]:1584.0 < 1430
# Coord: [1765.   75. 1921.  953.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1765.0 > 50
# coord[2]>q[2]:1921.0 < 838
# Coord: [1765.   75. 1921.  953.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1765.0 > 852
# coord[2]>q[2]:1921.0 < 1430
# Coord: [143. 151. 262. 619.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:143.0 > 50
# coord[2]>q[2]:262.0 < 838
# Coord: [143. 151. 262. 619.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:143.0 > 852
# coord[2]>q[2]:262.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [1515.  140. 1801.  942.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1515.0 > 50
# coord[2]>q[2]:1801.0 < 838
# Coord: [1515.  140. 1801.  942.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1515.0 > 852
# coord[2]>q[2]:1801.0 < 1430
# Coord: [423. 119. 661. 943.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:423.0 > 50
# coord[2]>q[2]:661.0 < 838
# Coord: [423. 119. 661. 943.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:423.0 > 852
# coord[2]>q[2]:661.0 < 1430
# Coord: [ 760.  123. 1039.  936.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:760.0 > 50
# coord[2]>q[2]:1039.0 < 838
# Coord: [ 760.  123. 1039.  936.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:760.0 > 852
# coord[2]>q[2]:1039.0 < 1430
# Coord: [1128.  118. 1446.  967.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1128.0 > 50
# coord[2]>q[2]:1446.0 < 838
# Coord: [1128.  118. 1446.  967.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1128.0 > 852
# coord[2]>q[2]:1446.0 < 1430
# Coord: [ 989.  124. 1195.  865.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:989.0 > 50
# coord[2]>q[2]:1195.0 < 838
# Coord: [ 989.  124. 1195.  865.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:989.0 > 852
# coord[2]>q[2]:1195.0 < 1430
# Coord: [1362.   73. 1583.  882.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1362.0 > 50
# coord[2]>q[2]:1583.0 < 838
# Coord: [1362.   73. 1583.  882.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1362.0 > 852
# coord[2]>q[2]:1583.0 < 1430
# Coord: [1762.   76. 1920.  949.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1762.0 > 50
# coord[2]>q[2]:1920.0 < 838
# Coord: [1762.   76. 1920.  949.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1762.0 > 852
# coord[2]>q[2]:1920.0 < 1430
# Coord: [143. 151. 264. 618.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:143.0 > 50
# coord[2]>q[2]:264.0 < 838
# Coord: [143. 151. 264. 618.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:143.0 > 852
# coord[2]>q[2]:264.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# Queues len:  2
# Coords len:  7
# Coord: [419. 114. 667. 947.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:419.0 > 50
# coord[2]>q[2]:667.0 < 838
# Coord: [419. 114. 667. 947.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:419.0 > 852
# coord[2]>q[2]:667.0 < 1430
# Coord: [1516.  138. 1803.  944.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1516.0 > 50
# coord[2]>q[2]:1803.0 < 838
# Coord: [1516.  138. 1803.  944.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1516.0 > 852
# coord[2]>q[2]:1803.0 < 1430
# Coord: [ 760.  123. 1043.  945.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:760.0 > 50
# coord[2]>q[2]:1043.0 < 838
# Coord: [ 760.  123. 1043.  945.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:760.0 > 852
# coord[2]>q[2]:1043.0 < 1430
# Coord: [1120.  120. 1447.  961.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1120.0 > 50
# coord[2]>q[2]:1447.0 < 838
# Coord: [1120.  120. 1447.  961.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1120.0 > 852
# coord[2]>q[2]:1447.0 < 1430
# Coord: [1370.   77. 1585.  864.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1370.0 > 50
# coord[2]>q[2]:1585.0 < 838
# Coord: [1370.   77. 1585.  864.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1370.0 > 852
# coord[2]>q[2]:1585.0 < 1430
# Coord: [1012.  138. 1193.  822.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1012.0 > 50
# coord[2]>q[2]:1193.0 < 838
# Coord: [1012.  138. 1193.  822.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1012.0 > 852
# coord[2]>q[2]:1193.0 < 1430
# Coord: [1756.   72. 1921.  951.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1756.0 > 50
# coord[2]>q[2]:1921.0 < 838
# Coord: [1756.   72. 1921.  951.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1756.0 > 852
# coord[2]>q[2]:1921.0 < 1430
# Total People in frame = 7
# Number of people in queue = {1: 0, 2: 1}
# Queues len:  2
# Coords len:  9
# Coord: [1514.  138. 1805.  945.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1514.0 > 50
# coord[2]>q[2]:1805.0 < 838
# Coord: [1514.  138. 1805.  945.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1514.0 > 852
# coord[2]>q[2]:1805.0 < 1430
# Coord: [416. 112. 670. 948.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:416.0 > 50
# coord[2]>q[2]:670.0 < 838
# Coord: [416. 112. 670. 948.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:416.0 > 852
# coord[2]>q[2]:670.0 < 1430
# Coord: [ 762.  121. 1047.  949.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:762.0 > 50
# coord[2]>q[2]:1047.0 < 838
# Coord: [ 762.  121. 1047.  949.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:762.0 > 852
# coord[2]>q[2]:1047.0 < 1430
# Coord: [1125.  118. 1446.  961.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1125.0 > 50
# coord[2]>q[2]:1446.0 < 838
# Coord: [1125.  118. 1446.  961.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1125.0 > 852
# coord[2]>q[2]:1446.0 < 1430
# Coord: [1368.   78. 1588.  857.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1368.0 > 50
# coord[2]>q[2]:1588.0 < 838
# Coord: [1368.   78. 1588.  857.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1368.0 > 852
# coord[2]>q[2]:1588.0 < 1430
# Coord: [1013.  134. 1205.  860.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1013.0 > 50
# coord[2]>q[2]:1205.0 < 838
# Coord: [1013.  134. 1205.  860.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1013.0 > 852
# coord[2]>q[2]:1205.0 < 1430
# Coord: [1752.   73. 1922.  958.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1752.0 > 50
# coord[2]>q[2]:1922.0 < 838
# Coord: [1752.   73. 1922.  958.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1752.0 > 852
# coord[2]>q[2]:1922.0 < 1430
# Coord: [145. 153. 265. 610.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:145.0 > 50
# coord[2]>q[2]:265.0 < 838
# Coord: [145. 153. 265. 610.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:145.0 > 852
# coord[2]>q[2]:265.0 < 1430
# Coord: [173. 235. 340. 714.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:173.0 > 50
# coord[2]>q[2]:340.0 < 838
# Coord: [173. 235. 340. 714.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:173.0 > 852
# coord[2]>q[2]:340.0 < 1430
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  8
# Coord: [1514.  140. 1805.  943.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1514.0 > 50
# coord[2]>q[2]:1805.0 < 838
# Coord: [1514.  140. 1805.  943.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1514.0 > 852
# coord[2]>q[2]:1805.0 < 1430
# Coord: [426. 121. 677. 948.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:426.0 > 50
# coord[2]>q[2]:677.0 < 838
# Coord: [426. 121. 677. 948.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:426.0 > 852
# coord[2]>q[2]:677.0 < 1430
# Coord: [ 764.  127. 1053.  947.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:764.0 > 50
# coord[2]>q[2]:1053.0 < 838
# Coord: [ 764.  127. 1053.  947.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:764.0 > 852
# coord[2]>q[2]:1053.0 < 1430
# Coord: [1120.  120. 1445.  959.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1120.0 > 50
# coord[2]>q[2]:1445.0 < 838
# Coord: [1120.  120. 1445.  959.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1120.0 > 852
# coord[2]>q[2]:1445.0 < 1430
# Coord: [1009.  128. 1210.  887.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1009.0 > 50
# coord[2]>q[2]:1210.0 < 838
# Coord: [1009.  128. 1210.  887.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1009.0 > 852
# coord[2]>q[2]:1210.0 < 1430
# Coord: [1374.   80. 1591.  857.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1374.0 > 50
# coord[2]>q[2]:1591.0 < 838
# Coord: [1374.   80. 1591.  857.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1374.0 > 852
# coord[2]>q[2]:1591.0 < 1430
# Coord: [1752.   75. 1921.  954.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:1752.0 > 50
# coord[2]>q[2]:1921.0 < 838
# Coord: [1752.   75. 1921.  954.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:1752.0 > 852
# coord[2]>q[2]:1921.0 < 1430
# Coord: [171. 232. 340. 718.]
# Queue: [ 50  90 838 794]
# coord[0]>q[0]:171.0 > 50
# coord[2]>q[2]:340.0 < 838
# Coord: [171. 232. 340. 718.]
# Queue: [ 852   74 1430  841]
# coord[0]>q[0]:171.0 > 852
# coord[2]>q[2]:340.0 < 1430
# Total People in frame = 8
# Number of people in queue = {1: 1, 2: 1}
# results/
# results/transportation/
# results/transportation/cpu/
# results/transportation/cpu/stats.txt
# results/transportation/cpu/output_video.mp4
# stderr.log

# %%
# !cat stderr.log
# Out:
# person_detect.py:55: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Transportation CPU', ['results/transportation/cpu/output_video.mp4'])
# Out:
# <h5>Transportation CPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/transportation/cpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.2: Submit to an Edge Compute Node with CPU and IGPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core i5-6500TE</a>. The inference workload should run on the **Intel® HD Graphics 530** integrated GPU.

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
#Submit job to the queue
gpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-hd-530 -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 GPU /data/resources/transportation.mp4 /data/queue_param/transportation.npy /output/results/transportation/gpu 7" -N store_core 

print(gpu_job_id[0])
# Out:
# SKbNVxzFAa6jQCz0fbOgMXoSc1u9KjD6

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(gpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:SKbNVxzFAa6jQCz0fbOgMXoSc1u9KjD6) are ready.
# Please wait......................................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 6, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 11
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 3}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 12
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 3}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 3}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# results/
# results/transportation/
# results/transportation/gpu/
# results/transportation/gpu/stats.txt
# results/transportation/gpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Transportation GPU', ['results/transportation/gpu/output_video.mp4'])
# Out:
# <h5>Transportation GPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/transportation/gpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.3: Submit to an Edge Compute Node with an Intel® Neural Compute Stick 2
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core i5-6500te CPU</a>. The inference workload should run on an <a
#     href="https://software.intel.com/en-us/neural-compute-stick">Intel Neural Compute Stick 2</a> installed in this  node.

# %%
#Submit job to the queue
vpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-ncs2 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 MYRIAD /data/resources/transportation.mp4 /data/queue_param/transportation.npy /output/results/transportation/vpu 7" -N store_core
 
print(vpu_job_id[0])
# Out:
# 0lfHwrEOtM4ptBwVCgs76uSZWvpUbpQZ

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(vpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:0lfHwrEOtM4ptBwVCgs76uSZWvpUbpQZ) are ready.
# Please wait.................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 6, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# results/
# results/transportation/
# results/transportation/vpu/
# results/transportation/vpu/stats.txt
# results/transportation/vpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Transportation VPU', ['results/transportation/vpu/output_video.mp4'])
# Out:
# <h5>Transportation VPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/transportation/vpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.4: Submit to an Edge Compute Node with IEI Mustang-F100-A10
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500te CPU</a> . The inference workload will run on the <a href="https://www.ieiworld.com/mustang-f100/en/"> IEI Mustang-F100-A10 </a> FPGA card installed in this node.

# %%
#Submit job to the queue
fpga_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te:iei-mustang-f100-a10 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 HETERO:FPGA,CPU /data/resources/transportation.mp4 /data/queue_param/transportation.npy /output/results/transportation/fpga 7" -N store_core

print(fpga_job_id[0])
# Out:
# 4OCkHxTsb1JtDCUNwxBEr17yJNwyXtx8

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(fpga_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:4OCkHxTsb1JtDCUNwxBEr17yJNwyXtx8) are ready.
# Please wait..................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# INTELFPGAOCLSDKROOT is not set
# Using script's current directory (/opt/altera/aocl-pro-rte/aclrte-linux64)
#
# aoc was not found, but aocl was found. Assuming only RTE is installed.
#
# AOCL_BOARD_PACKAGE_ROOT is set to /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2. Using that.
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/bin to PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/host/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/lib to LD_LIBRARY_PATH
# aocl program: Running program from /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/libexec
# Programming device: a10gx_2ddr : Intel Vision Accelerator Design with Intel Arria 10 FPGA (acla10_1150_sg20)
# Program succeed.
# Loading Network...
# Network loaded.
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 6, 2: 0}
# Total People in frame = 9
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 5, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 0}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 10
# Number of people in queue = {1: 5, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 3}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 3}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 11
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 4, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 3}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 9
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 10
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 0}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 6
# Number of people in queue = {1: 1, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 2}
# Total People in frame = 8
# Number of people in queue = {1: 3, 2: 2}
# Total People in frame = 7
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 7
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 8
# Number of people in queue = {1: 2, 2: 1}
# results/
# results/transportation/
# results/transportation/fpga/
# results/transportation/fpga/stats.txt
# results/transportation/fpga/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Transportation FPGA', ['results/transportation/fpga/output_video.mp4'])
# Out:
# <h5>Transportation FPGA</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/transportation/fpga/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ***Wait!***
#
# Please wait for all the inference jobs and video rendering to complete before proceeding to the next step.
#
# ## Step 2: Assess Performance
#
# Run the cells below to compare the performance across all 4 devices. The following timings for the model are being comapred across all 4 devices:
#
# - Model Loading Time
# - Average Inference Time
# - FPS

# %%
import matplotlib.pyplot as plt

device_list=['cpu', 'gpu', 'fpga', 'vpu']
inference_time=[]
fps=[]
model_load_time=[]

for device in device_list:
    with open('results/transportation/'+device+'/stats.txt', 'r') as f:
        inference_time.append(float(f.readline().split("\n")[0]))
        fps.append(float(f.readline().split("\n")[0]))
        model_load_time.append(float(f.readline().split("\n")[0]))

# %%
plt.bar(device_list, inference_time)
plt.xlabel("Device Used")
plt.ylabel("Total Inference Time in Seconds")
plt.show()

# %%
plt.bar(device_list, fps)
plt.xlabel("Device Used")
plt.ylabel("Frames per Second")
plt.show()

# %%
plt.bar(device_list, model_load_time)
plt.xlabel("Device Used")
plt.ylabel("Model Loading Time in Seconds")
plt.show()

# %% [markdown]
# # Step 3: Update Proposal Document
#
# Now that you've completed your hardware testing, you should go back to the proposal document and validate or update your originally proposed hardware. Once you've updated your proposal, you can move onto the next scenario.
