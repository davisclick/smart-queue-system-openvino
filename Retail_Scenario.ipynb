# %% [markdown]
# # Smart Queue Monitoring System - Retail Scenario
#
# ## Overview
# Now that you have your Python script and job submission script, you're ready to request an **IEI Tank-870** edge node and run inference on the different hardware types (CPU, GPU, VPU, FPGA).
#
# After the inference is completed, the output video and stats files need to be retrieved and stored in the workspace, which can then be viewed within the Jupyter Notebook.
#
# ## Objectives
# * Submit inference jobs to Intel's DevCloud using the `qsub` command.
# * Retrieve and review the results.
# * After testing, go back to the proposal doc and update your original proposed hardware device.

# %% [markdown]
# ## Step 0: Set Up
#
# #### IMPORTANT: Set up paths so we can run Dev Cloud utilities
# You *must* run this every time you enter a Workspace session.
# (Tip: select the cell and use **Shift+Enter** to run the cell.)

# %%
# %env PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support
import os
import sys
sys.path.insert(0, os.path.abspath('/opt/intel_devcloud_support'))
sys.path.insert(0, os.path.abspath('/opt/intel'))
# Out:
# env: PATH=/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/intel_devcloud_support

# %% [markdown]
# ### Step 0.1:  (Optional-step): Original Video
#
# If you are curious to see the input video, run the following cell to view the original video stream we'll be using for inference.

# %%
import videoHtml
videoHtml.videoHTML('Retail', ['original_videos/Retail.mp4'])
# Out:
# <h5>Retail</h5>
#         <video alt="" controls autoplay muted height="480"><source src="original_videos/Retail.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1 : Inference on a Video
#
# In the next few cells, You'll submit your job using the `qsub` command and retrieving the results for each job. Each of the cells below should submit a job to different edge compute nodes.
#
# The output of the cell is the `JobID` of your job, which you can use to track progress of a job with `liveQStat`.
#
# You will need to submit a job for each of the following hardware types:
# * **CPU**
# * **GPU**
# * **VPU**
# * **FPGA**
#
# **Note** You will have to submit each job one at a time and retrieve their results.
#
# After submission, they will go into a queue and run as soon as the requested compute resources become available.
# (Tip: **shift+enter** will run the cell and automatically move you to the next cell.)
#
# If your job successfully runs and completes, once you retrieve your results, it should output a video and a stats text file in the `results/retail/<DEVICE>` directory.
#
# For example, your **CPU** job should output its files in this directory:
# > **results/retail/cpu**
#
# **Note**: To get the queue labels for the different hardware devices, you can go to [this link](https://devcloud.intel.com/edge/get_started/devcloud/).
#
# The following arguments should be passed to the job submission script after the `-F` flag:
# * Model path - `/data/models/intel/person-detection-retail-0013/<MODEL PRECISION>/`. You will need to adjust this path based on the model precision being using on the hardware.
# * Device - `CPU`, `GPU`, `MYRIAD`, `HETERO:FPGA,CPU`
# * Manufacturing video path - `/data/resources/retail.mp4`
# * Manufacturing queue_param file path - `/data/queue_param/retail.npy`
# * Output path - `/output/results/retail/<DEVICE>` This should be adjusted based on the device used in the job.
# * Max num of people - This is the max number of people in queue before the system would redirect them to another queue.

# %% [markdown]
# ## Step 1.1: Submit to an Edge Compute Node with an Intel CPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a
#     href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core™ i5-6500TE processor</a>. The inference workload should run on the CPU.

# %%
#Submit job to the queue
cpu_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 CPU /data/resources/retail.mp4 /data/queue_param/retail.npy /output/results/retail/cpu 5" -N store_core

print(cpu_job_id[0])
# Out:
# DojpKpHL6L1HO3yMicbkJnXW1LFVc9UV

# %% [markdown]
# #### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(cpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:DojpKpHL6L1HO3yMicbkJnXW1LFVc9UV) are ready.
# Please wait.......Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1158.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1158.0 < 915
# Coord: [1076.   99. 1158.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1158.0 < 1264
# Coord: [711.   9. 813. 356.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:711.0 > 620
# coord[2]>q[2]:813.0 < 915
# Coord: [711.   9. 813. 356.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:711.0 > 1000
# coord[2]>q[2]:813.0 < 1264
# Coord: [910. 149. 994. 373.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 149. 994. 373.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [899.   0. 960. 183.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:899.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [899.   0. 960. 183.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:899.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [711.   7. 814. 357.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:711.0 > 620
# coord[2]>q[2]:814.0 < 915
# Coord: [711.   7. 814. 357.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:711.0 > 1000
# coord[2]>q[2]:814.0 < 1264
# Coord: [911. 149. 994. 373.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 373.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [899.   0. 960. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:899.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [899.   0. 960. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:899.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  5
# Coord: [1076.   99. 1158.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1158.0 < 915
# Coord: [1076.   99. 1158.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1158.0 < 1264
# Coord: [709.   7. 809. 353.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:709.0 > 620
# coord[2]>q[2]:809.0 < 915
# Coord: [709.   7. 809. 353.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:709.0 > 1000
# coord[2]>q[2]:809.0 < 1264
# Coord: [912. 151. 995. 372.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [912. 151. 995. 372.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Coord: [529.  81. 680. 593.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:529.0 > 620
# coord[2]>q[2]:680.0 < 915
# Coord: [529.  81. 680. 593.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:529.0 > 1000
# coord[2]>q[2]:680.0 < 1264
# Coord: [900.   0. 960. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [900.   0. 960. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [706.  10. 807. 353.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:706.0 > 620
# coord[2]>q[2]:807.0 < 915
# Coord: [706.  10. 807. 353.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:706.0 > 1000
# coord[2]>q[2]:807.0 < 1264
# Coord: [910. 148. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 148. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 960. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [900.   0. 960. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [706.  12. 806. 352.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:706.0 > 620
# coord[2]>q[2]:806.0 < 915
# Coord: [706.  12. 806. 352.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:706.0 > 1000
# coord[2]>q[2]:806.0 < 1264
# Coord: [910. 148. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 148. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [901.   0. 959. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:901.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [901.   0. 959. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:901.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1075.   99. 1158.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1075.0 > 620
# coord[2]>q[2]:1158.0 < 915
# Coord: [1075.   99. 1158.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1075.0 > 1000
# coord[2]>q[2]:1158.0 < 1264
# Coord: [707.  13. 805. 350.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:805.0 < 915
# Coord: [707.  13. 805. 350.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:805.0 < 1264
# Coord: [911. 151. 995. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [911. 151. 995. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Coord: [901.   0. 959. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:901.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [901.   0. 959. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:901.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [707.  16. 805. 351.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:805.0 < 915
# Coord: [707.  16. 805. 351.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:805.0 < 1264
# Coord: [911. 151. 995. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [911. 151. 995. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Coord: [901.   0. 959. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:901.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [901.   0. 959. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:901.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   98. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   98. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [707.  22. 806. 349.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:806.0 < 915
# Coord: [707.  22. 806. 349.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:806.0 < 1264
# Coord: [911. 151. 995. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [911. 151. 995. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Coord: [901.   0. 959. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:901.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [901.   0. 959. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:901.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [708.  21. 807. 348.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:708.0 > 620
# coord[2]>q[2]:807.0 < 915
# Coord: [708.  21. 807. 348.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:708.0 > 1000
# coord[2]>q[2]:807.0 < 1264
# Coord: [911. 151. 994. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 151. 994. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 960. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [900.   0. 960. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1077.   99. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1077.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1077.   99. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1077.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [709.  45. 815. 356.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:709.0 > 620
# coord[2]>q[2]:815.0 < 915
# Coord: [709.  45. 815. 356.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:709.0 > 1000
# coord[2]>q[2]:815.0 < 1264
# Coord: [910. 149. 993. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [910. 149. 993. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [900.   0. 959. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [900.   0. 959. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [710.  21. 811. 348.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:710.0 > 620
# coord[2]>q[2]:811.0 < 915
# Coord: [710.  21. 811. 348.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:710.0 > 1000
# coord[2]>q[2]:811.0 < 1264
# Coord: [910. 149. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 149. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 960. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [900.   0. 960. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.   99. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1076.   99. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [710.  18. 811. 350.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:710.0 > 620
# coord[2]>q[2]:811.0 < 915
# Coord: [710.  18. 811. 350.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:710.0 > 1000
# coord[2]>q[2]:811.0 < 1264
# Coord: [911. 149. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 959. 182.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [900.   0. 959. 182.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1075.   98. 1159.  364.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1075.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1075.   98. 1159.  364.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1075.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [711.  51. 816. 357.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:711.0 > 620
# coord[2]>q[2]:816.0 < 915
# Coord: [711.  51. 816. 357.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:711.0 > 1000
# coord[2]>q[2]:816.0 < 1264
# Coord: [911. 149. 994. 372.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 372.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 959. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [900.   0. 959. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1075.   98. 1159.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1075.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1075.   98. 1159.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1075.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [708.  54. 816. 354.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:708.0 > 620
# coord[2]>q[2]:816.0 < 915
# Coord: [708.  54. 816. 354.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:708.0 > 1000
# coord[2]>q[2]:816.0 < 1264
# Coord: [911. 149. 994. 374.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 374.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 959. 182.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [900.   0. 959. 182.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1073.   97. 1159.  366.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1073.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1073.   97. 1159.  366.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1073.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [706.  65. 815. 357.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:706.0 > 620
# coord[2]>q[2]:815.0 < 915
# Coord: [706.  65. 815. 357.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:706.0 > 1000
# coord[2]>q[2]:815.0 < 1264
# Coord: [911. 149. 994. 374.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 374.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [900.   0. 960. 182.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:900.0 > 620
# coord[2]>q[2]:960.0 < 915
# Coord: [900.   0. 960. 182.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:900.0 > 1000
# coord[2]>q[2]:960.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [1073.   98. 1159.  368.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1073.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1073.   98. 1159.  368.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1073.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [707.  54. 816. 352.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:816.0 < 915
# Coord: [707.  54. 816. 352.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:816.0 < 1264
# Coord: [910. 149. 994. 372.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 149. 994. 372.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [1074.   98. 1159.  366.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1074.0 > 620
# coord[2]>q[2]:1159.0 < 915
# Coord: [1074.   98. 1159.  366.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1074.0 > 1000
# coord[2]>q[2]:1159.0 < 1264
# Coord: [706.  29. 812. 343.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:706.0 > 620
# coord[2]>q[2]:812.0 < 915
# Coord: [706.  29. 812. 343.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:706.0 > 1000
# coord[2]>q[2]:812.0 < 1264
# Coord: [911. 151. 995. 372.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [911. 151. 995. 372.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [1073.   98. 1160.  367.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1073.0 > 620
# coord[2]>q[2]:1160.0 < 915
# Coord: [1073.   98. 1160.  367.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1073.0 > 1000
# coord[2]>q[2]:1160.0 < 1264
# Coord: [707.  53. 822. 353.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:822.0 < 915
# Coord: [707.  53. 822. 353.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:822.0 < 1264
# Coord: [911. 152. 995. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [911. 152. 995. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [1075.   99. 1162.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1075.0 > 620
# coord[2]>q[2]:1162.0 < 915
# Coord: [1075.   99. 1162.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1075.0 > 1000
# coord[2]>q[2]:1162.0 < 1264
# Coord: [715.  45. 832. 352.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:715.0 > 620
# coord[2]>q[2]:832.0 < 915
# Coord: [715.  45. 832. 352.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:715.0 > 1000
# coord[2]>q[2]:832.0 < 1264
# Coord: [910. 152. 995. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [910. 152. 995. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1076.  100. 1164.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1164.0 < 915
# Coord: [1076.  100. 1164.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1164.0 < 1264
# Coord: [719.  42. 833. 357.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:719.0 > 620
# coord[2]>q[2]:833.0 < 915
# Coord: [719.  42. 833. 357.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:719.0 > 1000
# coord[2]>q[2]:833.0 < 1264
# Coord: [514. 153. 585. 441.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:514.0 > 620
# coord[2]>q[2]:585.0 < 915
# Coord: [514. 153. 585. 441.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:514.0 > 1000
# coord[2]>q[2]:585.0 < 1264
# Coord: [910. 149. 994. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:910.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [910. 149. 994. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:910.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 4}
# Queues len:  2
# Coords len:  4
# Coord: [721.  42. 832. 359.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:832.0 < 915
# Coord: [721.  42. 832. 359.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:832.0 < 1264
# Coord: [1077.  100. 1166.  364.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1077.0 > 620
# coord[2]>q[2]:1166.0 < 915
# Coord: [1077.  100. 1166.  364.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1077.0 > 1000
# coord[2]>q[2]:1166.0 < 1264
# Coord: [909. 149. 994. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [909. 149. 994. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [506. 150. 586. 471.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:506.0 > 620
# coord[2]>q[2]:586.0 < 915
# Coord: [506. 150. 586. 471.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:506.0 > 1000
# coord[2]>q[2]:586.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [725.  69. 835. 363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:725.0 > 620
# coord[2]>q[2]:835.0 < 915
# Coord: [725.  69. 835. 363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:725.0 > 1000
# coord[2]>q[2]:835.0 < 1264
# Coord: [1076.  103. 1167.  363.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1167.0 < 915
# Coord: [1076.  103. 1167.  363.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1167.0 < 1264
# Coord: [909. 149. 994. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [909. 149. 994. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [726.   2. 812. 265.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:812.0 < 915
# Coord: [726.   2. 812. 265.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:812.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 4}
# Queues len:  2
# Coords len:  5
# Coord: [729.  69. 837. 365.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:729.0 > 620
# coord[2]>q[2]:837.0 < 915
# Coord: [729.  69. 837. 365.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:729.0 > 1000
# coord[2]>q[2]:837.0 < 1264
# Coord: [1076.  105. 1171.  368.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1076.0 > 620
# coord[2]>q[2]:1171.0 < 915
# Coord: [1076.  105. 1171.  368.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1076.0 > 1000
# coord[2]>q[2]:1171.0 < 1264
# Coord: [908. 148. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 148. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [726.   1. 810. 261.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:810.0 < 915
# Coord: [726.   1. 810. 261.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:810.0 < 1264
# Coord: [508. 154. 597. 455.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:508.0 > 620
# coord[2]>q[2]:597.0 < 915
# Coord: [508. 154. 597. 455.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:508.0 > 1000
# coord[2]>q[2]:597.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 4, 2: 4}
# Queues len:  2
# Coords len:  5
# Coord: [728.  86. 837. 365.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:728.0 > 620
# coord[2]>q[2]:837.0 < 915
# Coord: [728.  86. 837. 365.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:728.0 > 1000
# coord[2]>q[2]:837.0 < 1264
# Coord: [1077.  104. 1174.  368.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1077.0 > 620
# coord[2]>q[2]:1174.0 < 915
# Coord: [1077.  104. 1174.  368.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1077.0 > 1000
# coord[2]>q[2]:1174.0 < 1264
# Coord: [726.   2. 807. 246.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:807.0 < 915
# Coord: [726.   2. 807. 246.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:807.0 < 1264
# Coord: [908. 148. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 148. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [502. 152. 587. 445.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:502.0 > 620
# coord[2]>q[2]:587.0 < 915
# Coord: [502. 152. 587. 445.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:502.0 > 1000
# coord[2]>q[2]:587.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  5
# Coord: [1081.  106. 1178.  378.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1081.0 > 620
# coord[2]>q[2]:1178.0 < 915
# Coord: [1081.  106. 1178.  378.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1081.0 > 1000
# coord[2]>q[2]:1178.0 < 1264
# Coord: [732.  47. 831. 353.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:732.0 > 620
# coord[2]>q[2]:831.0 < 915
# Coord: [732.  47. 831. 353.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:732.0 > 1000
# coord[2]>q[2]:831.0 < 1264
# Coord: [503. 149. 590. 473.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:503.0 > 620
# coord[2]>q[2]:590.0 < 915
# Coord: [503. 149. 590. 473.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:503.0 > 1000
# coord[2]>q[2]:590.0 < 1264
# Coord: [726.   2. 807. 259.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:807.0 < 915
# Coord: [726.   2. 807. 259.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:807.0 < 1264
# Coord: [908. 148. 994. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 148. 994. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  4
# Coord: [1080.  111. 1181.  381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1080.0 > 620
# coord[2]>q[2]:1181.0 < 915
# Coord: [1080.  111. 1181.  381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1080.0 > 1000
# coord[2]>q[2]:1181.0 < 1264
# Coord: [731.  42. 834. 351.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:731.0 > 620
# coord[2]>q[2]:834.0 < 915
# Coord: [731.  42. 834. 351.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:731.0 > 1000
# coord[2]>q[2]:834.0 < 1264
# Coord: [499. 158. 585. 463.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:499.0 > 620
# coord[2]>q[2]:585.0 < 915
# Coord: [499. 158. 585. 463.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:499.0 > 1000
# coord[2]>q[2]:585.0 < 1264
# Coord: [908. 149. 994. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 149. 994. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [1080.  117. 1182.  385.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1080.0 > 620
# coord[2]>q[2]:1182.0 < 915
# Coord: [1080.  117. 1182.  385.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1080.0 > 1000
# coord[2]>q[2]:1182.0 < 1264
# Coord: [732.  45. 831. 342.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:732.0 > 620
# coord[2]>q[2]:831.0 < 915
# Coord: [732.  45. 831. 342.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:732.0 > 1000
# coord[2]>q[2]:831.0 < 1264
# Coord: [503. 157. 586. 464.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:503.0 > 620
# coord[2]>q[2]:586.0 < 915
# Coord: [503. 157. 586. 464.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:503.0 > 1000
# coord[2]>q[2]:586.0 < 1264
# Coord: [908. 149. 995. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [908. 149. 995. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  5
# Coord: [744.  83. 846. 362.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:744.0 > 620
# coord[2]>q[2]:846.0 < 915
# Coord: [744.  83. 846. 362.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:744.0 > 1000
# coord[2]>q[2]:846.0 < 1264
# Coord: [726.   5. 812. 300.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:812.0 < 915
# Coord: [726.   5. 812. 300.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:812.0 < 1264
# Coord: [1081.  119. 1185.  390.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1081.0 > 620
# coord[2]>q[2]:1185.0 < 915
# Coord: [1081.  119. 1185.  390.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1081.0 > 1000
# coord[2]>q[2]:1185.0 < 1264
# Coord: [501. 157. 582. 455.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:501.0 > 620
# coord[2]>q[2]:582.0 < 915
# Coord: [501. 157. 582. 455.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:501.0 > 1000
# coord[2]>q[2]:582.0 < 1264
# Coord: [908. 149. 994. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 149. 994. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  5
# Coord: [748.  87. 855. 368.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:748.0 > 620
# coord[2]>q[2]:855.0 < 915
# Coord: [748.  87. 855. 368.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:748.0 > 1000
# coord[2]>q[2]:855.0 < 1264
# Coord: [726.   7. 809. 277.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:726.0 > 620
# coord[2]>q[2]:809.0 < 915
# Coord: [726.   7. 809. 277.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:726.0 > 1000
# coord[2]>q[2]:809.0 < 1264
# Coord: [1085.  122. 1189.  384.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1085.0 > 620
# coord[2]>q[2]:1189.0 < 915
# Coord: [1085.  122. 1189.  384.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1085.0 > 1000
# coord[2]>q[2]:1189.0 < 1264
# Coord: [497. 156. 577. 446.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:497.0 > 620
# coord[2]>q[2]:577.0 < 915
# Coord: [497. 156. 577. 446.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:497.0 > 1000
# coord[2]>q[2]:577.0 < 1264
# Coord: [908. 149. 994. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [908. 149. 994. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  5
# Coord: [753.  87. 856. 388.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:753.0 > 620
# coord[2]>q[2]:856.0 < 915
# Coord: [753.  87. 856. 388.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:753.0 > 1000
# coord[2]>q[2]:856.0 < 1264
# Coord: [725.   4. 808. 261.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:725.0 > 620
# coord[2]>q[2]:808.0 < 915
# Coord: [725.   4. 808. 261.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:725.0 > 1000
# coord[2]>q[2]:808.0 < 1264
# Coord: [497. 157. 576. 460.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:497.0 > 620
# coord[2]>q[2]:576.0 < 915
# Coord: [497. 157. 576. 460.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:497.0 > 1000
# coord[2]>q[2]:576.0 < 1264
# Coord: [1089.  126. 1193.  390.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1089.0 > 620
# coord[2]>q[2]:1193.0 < 915
# Coord: [1089.  126. 1193.  390.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1089.0 > 1000
# coord[2]>q[2]:1193.0 < 1264
# Coord: [908. 149. 995. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:908.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [908. 149. 995. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:908.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  5
# Coord: [759.  90. 857. 398.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:759.0 > 620
# coord[2]>q[2]:857.0 < 915
# Coord: [759.  90. 857. 398.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:759.0 > 1000
# coord[2]>q[2]:857.0 < 1264
# Coord: [721.   4. 805. 269.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:805.0 < 915
# Coord: [721.   4. 805. 269.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:805.0 < 1264
# Coord: [1091.  127. 1197.  391.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1091.0 > 620
# coord[2]>q[2]:1197.0 < 915
# Coord: [1091.  127. 1197.  391.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1091.0 > 1000
# coord[2]>q[2]:1197.0 < 1264
# Coord: [494. 165. 577. 466.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:494.0 > 620
# coord[2]>q[2]:577.0 < 915
# Coord: [494. 165. 577. 466.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:494.0 > 1000
# coord[2]>q[2]:577.0 < 1264
# Coord: [909. 149. 995. 369.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:995.0 < 915
# Coord: [909. 149. 995. 369.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:995.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  5
# Coord: [762.  98. 855. 404.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:762.0 > 620
# coord[2]>q[2]:855.0 < 915
# Coord: [762.  98. 855. 404.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:762.0 > 1000
# coord[2]>q[2]:855.0 < 1264
# Coord: [722.   5. 800. 261.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:722.0 > 620
# coord[2]>q[2]:800.0 < 915
# Coord: [722.   5. 800. 261.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:722.0 > 1000
# coord[2]>q[2]:800.0 < 1264
# Coord: [1094.  130. 1201.  395.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1094.0 > 620
# coord[2]>q[2]:1201.0 < 915
# Coord: [1094.  130. 1201.  395.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1094.0 > 1000
# coord[2]>q[2]:1201.0 < 1264
# Coord: [493. 170. 574. 468.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:493.0 > 620
# coord[2]>q[2]:574.0 < 915
# Coord: [493. 170. 574. 468.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:493.0 > 1000
# coord[2]>q[2]:574.0 < 1264
# Coord: [909. 148. 994. 371.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [909. 148. 994. 371.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  5
# Coord: [765.  94. 857. 409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:765.0 > 620
# coord[2]>q[2]:857.0 < 915
# Coord: [765.  94. 857. 409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:765.0 > 1000
# coord[2]>q[2]:857.0 < 1264
# Coord: [1092.  128. 1202.  400.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1092.0 > 620
# coord[2]>q[2]:1202.0 < 915
# Coord: [1092.  128. 1202.  400.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1092.0 > 1000
# coord[2]>q[2]:1202.0 < 1264
# Coord: [721.   5. 798. 270.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:798.0 < 915
# Coord: [721.   5. 798. 270.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:798.0 < 1264
# Coord: [487. 178. 573. 459.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:487.0 > 620
# coord[2]>q[2]:573.0 < 915
# Coord: [487. 178. 573. 459.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:487.0 > 1000
# coord[2]>q[2]:573.0 < 1264
# Coord: [911. 149. 993. 372.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 149. 993. 372.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 5
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  6
# Coord: [764. 106. 860. 417.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:764.0 > 620
# coord[2]>q[2]:860.0 < 915
# Coord: [764. 106. 860. 417.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:764.0 > 1000
# coord[2]>q[2]:860.0 < 1264
# Coord: [1093.  130. 1203.  394.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1093.0 > 620
# coord[2]>q[2]:1203.0 < 915
# Coord: [1093.  130. 1203.  394.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1093.0 > 1000
# coord[2]>q[2]:1203.0 < 1264
# Coord: [720.   6. 798. 272.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:720.0 > 620
# coord[2]>q[2]:798.0 < 915
# Coord: [720.   6. 798. 272.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:720.0 > 1000
# coord[2]>q[2]:798.0 < 1264
# Coord: [481. 183. 573. 458.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:481.0 > 620
# coord[2]>q[2]:573.0 < 915
# Coord: [481. 183. 573. 458.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:481.0 > 1000
# coord[2]>q[2]:573.0 < 1264
# Coord: [911. 149. 994. 377.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 377.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [898.   3. 958. 178.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:898.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [898.   3. 958. 178.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:898.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 6, 2: 6}
# Queues len:  2
# Coords len:  6
# Coord: [762. 107. 862. 424.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:762.0 > 620
# coord[2]>q[2]:862.0 < 915
# Coord: [762. 107. 862. 424.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:762.0 > 1000
# coord[2]>q[2]:862.0 < 1264
# Coord: [718.   7. 798. 278.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:718.0 > 620
# coord[2]>q[2]:798.0 < 915
# Coord: [718.   7. 798. 278.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:718.0 > 1000
# coord[2]>q[2]:798.0 < 1264
# Coord: [1094.  132. 1203.  392.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1094.0 > 620
# coord[2]>q[2]:1203.0 < 915
# Coord: [1094.  132. 1203.  392.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1094.0 > 1000
# coord[2]>q[2]:1203.0 < 1264
# Coord: [911. 149. 994. 379.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 149. 994. 379.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [478. 187. 573. 460.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:478.0 > 620
# coord[2]>q[2]:573.0 < 915
# Coord: [478. 187. 573. 460.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:478.0 > 1000
# coord[2]>q[2]:573.0 < 1264
# Coord: [897.   3. 958. 179.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:897.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [897.   3. 958. 179.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:897.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 6, 2: 6}
# Queues len:  2
# Coords len:  6
# Coord: [764. 109. 863. 430.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:764.0 > 620
# coord[2]>q[2]:863.0 < 915
# Coord: [764. 109. 863. 430.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:764.0 > 1000
# coord[2]>q[2]:863.0 < 1264
# Coord: [714.   8. 797. 273.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:714.0 > 620
# coord[2]>q[2]:797.0 < 915
# Coord: [714.   8. 797. 273.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:714.0 > 1000
# coord[2]>q[2]:797.0 < 1264
# Coord: [1099.  132. 1203.  393.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1099.0 > 620
# coord[2]>q[2]:1203.0 < 915
# Coord: [1099.  132. 1203.  393.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1099.0 > 1000
# coord[2]>q[2]:1203.0 < 1264
# Coord: [912. 149. 994. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 149. 994. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [473. 190. 575. 465.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:473.0 > 620
# coord[2]>q[2]:575.0 < 915
# Coord: [473. 190. 575. 465.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:473.0 > 1000
# coord[2]>q[2]:575.0 < 1264
# Coord: [897.   2. 958. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:897.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [897.   2. 958. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:897.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 6, 2: 5}
# Queues len:  2
# Coords len:  6
# Coord: [766. 105. 865. 436.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:766.0 > 620
# coord[2]>q[2]:865.0 < 915
# Coord: [766. 105. 865. 436.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:766.0 > 1000
# coord[2]>q[2]:865.0 < 1264
# Coord: [712.   7. 796. 273.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:712.0 > 620
# coord[2]>q[2]:796.0 < 915
# Coord: [712.   7. 796. 273.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:712.0 > 1000
# coord[2]>q[2]:796.0 < 1264
# Coord: [1099.  133. 1203.  395.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1099.0 > 620
# coord[2]>q[2]:1203.0 < 915
# Coord: [1099.  133. 1203.  395.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1099.0 > 1000
# coord[2]>q[2]:1203.0 < 1264
# Coord: [913. 148. 994. 380.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:913.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [913. 148. 994. 380.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:913.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [472. 195. 573. 460.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:472.0 > 620
# coord[2]>q[2]:573.0 < 915
# Coord: [472. 195. 573. 460.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:472.0 > 1000
# coord[2]>q[2]:573.0 < 1264
# Coord: [896.   1. 958. 181.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:896.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [896.   1. 958. 181.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:896.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 5}
# Queues len:  2
# Coords len:  6
# Coord: [765. 114. 867. 440.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:765.0 > 620
# coord[2]>q[2]:867.0 < 915
# Coord: [765. 114. 867. 440.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:765.0 > 1000
# coord[2]>q[2]:867.0 < 1264
# Coord: [707.   8. 793. 269.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:707.0 > 620
# coord[2]>q[2]:793.0 < 915
# Coord: [707.   8. 793. 269.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:707.0 > 1000
# coord[2]>q[2]:793.0 < 1264
# Coord: [1100.  132. 1202.  405.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1100.0 > 620
# coord[2]>q[2]:1202.0 < 915
# Coord: [1100.  132. 1202.  405.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1100.0 > 1000
# coord[2]>q[2]:1202.0 < 1264
# Coord: [914. 149. 994. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:914.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [914. 149. 994. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:914.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [473. 198. 574. 464.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:473.0 > 620
# coord[2]>q[2]:574.0 < 915
# Coord: [473. 198. 574. 464.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:473.0 > 1000
# coord[2]>q[2]:574.0 < 1264
# Coord: [896.   1. 958. 180.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:896.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [896.   1. 958. 180.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:896.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  6
# Coord: [766. 120. 869. 441.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:766.0 > 620
# coord[2]>q[2]:869.0 < 915
# Coord: [766. 120. 869. 441.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:766.0 > 1000
# coord[2]>q[2]:869.0 < 1264
# Coord: [704.   7. 791. 272.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:704.0 > 620
# coord[2]>q[2]:791.0 < 915
# Coord: [704.   7. 791. 272.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:704.0 > 1000
# coord[2]>q[2]:791.0 < 1264
# Coord: [1098.  132. 1202.  407.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1098.0 > 620
# coord[2]>q[2]:1202.0 < 915
# Coord: [1098.  132. 1202.  407.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1098.0 > 1000
# coord[2]>q[2]:1202.0 < 1264
# Coord: [915. 149. 994. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:915.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [915. 149. 994. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:915.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [472. 199. 574. 465.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:472.0 > 620
# coord[2]>q[2]:574.0 < 915
# Coord: [472. 199. 574. 465.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:472.0 > 1000
# coord[2]>q[2]:574.0 < 1264
# Coord: [895.   1. 958. 179.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:895.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [895.   1. 958. 179.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:895.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  6
# Coord: [768. 123. 870. 437.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:768.0 > 620
# coord[2]>q[2]:870.0 < 915
# Coord: [768. 123. 870. 437.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:768.0 > 1000
# coord[2]>q[2]:870.0 < 1264
# Coord: [700.   8. 791. 276.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:700.0 > 620
# coord[2]>q[2]:791.0 < 915
# Coord: [700.   8. 791. 276.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:700.0 > 1000
# coord[2]>q[2]:791.0 < 1264
# Coord: [1096.  133. 1202.  408.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1096.0 > 620
# coord[2]>q[2]:1202.0 < 915
# Coord: [1096.  133. 1202.  408.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1096.0 > 1000
# coord[2]>q[2]:1202.0 < 1264
# Coord: [916. 151. 993. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:916.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [916. 151. 993. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:916.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [471. 196. 574. 472.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:471.0 > 620
# coord[2]>q[2]:574.0 < 915
# Coord: [471. 196. 574. 472.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:471.0 > 1000
# coord[2]>q[2]:574.0 < 1264
# Coord: [896.   1. 959. 177.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:896.0 > 620
# coord[2]>q[2]:959.0 < 915
# Coord: [896.   1. 959. 177.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:896.0 > 1000
# coord[2]>q[2]:959.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  6
# Coord: [766. 124. 870. 442.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:766.0 > 620
# coord[2]>q[2]:870.0 < 915
# Coord: [766. 124. 870. 442.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:766.0 > 1000
# coord[2]>q[2]:870.0 < 1264
# Coord: [697.  10. 793. 277.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:697.0 > 620
# coord[2]>q[2]:793.0 < 915
# Coord: [697.  10. 793. 277.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:697.0 > 1000
# coord[2]>q[2]:793.0 < 1264
# Coord: [1097.  133. 1202.  407.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1097.0 > 620
# coord[2]>q[2]:1202.0 < 915
# Coord: [1097.  133. 1202.  407.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1097.0 > 1000
# coord[2]>q[2]:1202.0 < 1264
# Coord: [916. 151. 993. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:916.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [916. 151. 993. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:916.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [471. 189. 574. 482.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:471.0 > 620
# coord[2]>q[2]:574.0 < 915
# Coord: [471. 189. 574. 482.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:471.0 > 1000
# coord[2]>q[2]:574.0 < 1264
# Coord: [895.   1. 958. 177.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:895.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [895.   1. 958. 177.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:895.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  6
# Coord: [764. 136. 870. 436.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:764.0 > 620
# coord[2]>q[2]:870.0 < 915
# Coord: [764. 136. 870. 436.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:764.0 > 1000
# coord[2]>q[2]:870.0 < 1264
# Coord: [695.  11. 792. 278.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:695.0 > 620
# coord[2]>q[2]:792.0 < 915
# Coord: [695.  11. 792. 278.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:695.0 > 1000
# coord[2]>q[2]:792.0 < 1264
# Coord: [1097.  133. 1201.  408.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1097.0 > 620
# coord[2]>q[2]:1201.0 < 915
# Coord: [1097.  133. 1201.  408.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1097.0 > 1000
# coord[2]>q[2]:1201.0 < 1264
# Coord: [916. 151. 993. 380.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:916.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [916. 151. 993. 380.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:916.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [474. 185. 570. 478.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:474.0 > 620
# coord[2]>q[2]:570.0 < 915
# Coord: [474. 185. 570. 478.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:474.0 > 1000
# coord[2]>q[2]:570.0 < 1264
# Coord: [895.   1. 958. 176.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:895.0 > 620
# coord[2]>q[2]:958.0 < 915
# Coord: [895.   1. 958. 176.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:895.0 > 1000
# coord[2]>q[2]:958.0 < 1264
# Total People in frame = 6
# Number of people in queue = {1: 5, 2: 4}
# Queues len:  2
# Coords len:  6
# Coord: [764. 138. 870. 438.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:764.0 > 620
# coord[2]>q[2]:870.0 < 915
# Coord: [764. 138. 870. 438.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:764.0 > 1000
# coord[2]>q[2]:870.0 < 1264
# Coord: [695.  10. 793. 276.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:695.0 > 620
# coord[2]>q[2]:793.0 < 915
# Coord: [695.  10. 793. 276.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:695.0 > 1000
# coord[2]>q[2]:793.0 < 1264
# Coord: [476. 181. 570. 475.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:476.0 > 620
# coord[2]>q[2]:570.0 < 915
# Coord: [476. 181. 570. 475.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:476.0 > 1000
# coord[2]>q[2]:570.0 < 1264
# Coord: [1096.  132. 1201.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1096.0 > 620
# coord[2]>q[2]:1201.0 < 915
# Coord: [1096.  132. 1201.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1096.0 > 1000
# coord[2]>q[2]:1201.0 < 1264
# Coord: [916. 151. 993. 379.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:916.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [916. 151. 993. 379.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:916.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# ...
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [516. 158. 609. 448.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:516.0 > 620
# coord[2]>q[2]:609.0 < 915
# Coord: [516. 158. 609. 448.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:516.0 > 1000
# coord[2]>q[2]:609.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 4}
# Queues len:  2
# Coords len:  3
# Coord: [716.  76. 813. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:716.0 > 620
# coord[2]>q[2]:813.0 < 915
# Coord: [716.  76. 813. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:716.0 > 1000
# coord[2]>q[2]:813.0 < 1264
# Coord: [1106.  136. 1208.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1208.0 < 915
# Coord: [1106.  136. 1208.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1208.0 < 1264
# Coord: [912. 151. 993. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [912. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [721.  78. 815. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:815.0 < 915
# Coord: [721.  78. 815. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:815.0 < 1264
# Coord: [1105.  136. 1208.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1105.0 > 620
# coord[2]>q[2]:1208.0 < 915
# Coord: [1105.  136. 1208.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1105.0 > 1000
# coord[2]>q[2]:1208.0 < 1264
# Coord: [912. 151. 993. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [912. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [718.  78. 817. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:718.0 > 620
# coord[2]>q[2]:817.0 < 915
# Coord: [718.  78. 817. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:718.0 > 1000
# coord[2]>q[2]:817.0 < 1264
# Coord: [1106.  136. 1208.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1208.0 < 915
# Coord: [1106.  136. 1208.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1208.0 < 1264
# Coord: [911. 151. 993. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [721.  78. 819. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:819.0 < 915
# Coord: [721.  78. 819. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:819.0 < 1264
# Coord: [1105.  136. 1208.  411.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1105.0 > 620
# coord[2]>q[2]:1208.0 < 915
# Coord: [1105.  136. 1208.  411.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1105.0 > 1000
# coord[2]>q[2]:1208.0 < 1264
# Coord: [911. 151. 993. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [720.  78. 820. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:720.0 > 620
# coord[2]>q[2]:820.0 < 915
# Coord: [720.  78. 820. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:720.0 > 1000
# coord[2]>q[2]:820.0 < 1264
# Coord: [911. 151. 993. 370.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 151. 993. 370.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [1106.  136. 1208.  412.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1208.0 < 915
# Coord: [1106.  136. 1208.  412.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1208.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [721.  75. 823. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:721.0 > 620
# coord[2]>q[2]:823.0 < 915
# Coord: [721.  75. 823. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:721.0 > 1000
# coord[2]>q[2]:823.0 < 1264
# Coord: [1104.  135. 1207.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1104.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1104.  135. 1207.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1104.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Coord: [912. 150. 994. 385.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 385.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [520. 165. 599. 461.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:520.0 > 620
# coord[2]>q[2]:599.0 < 915
# Coord: [520. 165. 599. 461.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:520.0 > 1000
# coord[2]>q[2]:599.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [722.  81. 824. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:722.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [722.  81. 824. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:722.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [1105.  135. 1207.  412.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1105.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1105.  135. 1207.  412.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1105.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Coord: [912. 150. 994. 385.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 385.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [517. 165. 599. 464.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:517.0 > 620
# coord[2]>q[2]:599.0 < 915
# Coord: [517. 165. 599. 464.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:517.0 > 1000
# coord[2]>q[2]:599.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [723.  83. 825. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:723.0 > 620
# coord[2]>q[2]:825.0 < 915
# Coord: [723.  83. 825. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:723.0 > 1000
# coord[2]>q[2]:825.0 < 1264
# Coord: [1106.  135. 1207.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1106.  135. 1207.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Coord: [912. 150. 994. 387.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 387.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [723.  90. 824. 386.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:723.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [723.  90. 824. 386.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:723.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [518. 163. 596. 464.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:518.0 > 620
# coord[2]>q[2]:596.0 < 915
# Coord: [518. 163. 596. 464.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:518.0 > 1000
# coord[2]>q[2]:596.0 < 1264
# Coord: [1105.  134. 1206.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1105.0 > 620
# coord[2]>q[2]:1206.0 < 915
# Coord: [1105.  134. 1206.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1105.0 > 1000
# coord[2]>q[2]:1206.0 < 1264
# Coord: [912. 150. 994. 387.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 387.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [724.  89. 826. 388.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:724.0 > 620
# coord[2]>q[2]:826.0 < 915
# Coord: [724.  89. 826. 388.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:724.0 > 1000
# coord[2]>q[2]:826.0 < 1264
# Coord: [1105.  135. 1207.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1105.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1105.  135. 1207.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1105.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Coord: [513. 161. 599. 482.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:513.0 > 620
# coord[2]>q[2]:599.0 < 915
# Coord: [513. 161. 599. 482.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:513.0 > 1000
# coord[2]>q[2]:599.0 < 1264
# Coord: [912. 150. 994. 389.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 389.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [724.  89. 824. 385.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:724.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [724.  89. 824. 385.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:724.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [912. 150. 994. 388.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:912.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [912. 150. 994. 388.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:912.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Coord: [1106.  136. 1206.  410.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1206.0 < 915
# Coord: [1106.  136. 1206.  410.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1206.0 < 1264
# Coord: [514. 160. 595. 471.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:514.0 > 620
# coord[2]>q[2]:595.0 < 915
# Coord: [514. 160. 595. 471.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:514.0 > 1000
# coord[2]>q[2]:595.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  4
# Coord: [718.  86. 824. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:718.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [718.  86. 824. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:718.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [911. 150. 993. 386.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 150. 993. 386.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Coord: [1106.  136. 1206.  408.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1206.0 < 915
# Coord: [1106.  136. 1206.  408.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1206.0 < 1264
# Coord: [515. 157. 595. 467.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:515.0 > 620
# coord[2]>q[2]:595.0 < 915
# Coord: [515. 157. 595. 467.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:515.0 > 1000
# coord[2]>q[2]:595.0 < 1264
# Total People in frame = 4
# Number of people in queue = {1: 4, 2: 3}
# Queues len:  2
# Coords len:  3
# Coord: [713.  89. 824. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:713.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [713.  89. 824. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:713.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [1106.  135. 1206.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1206.0 < 915
# Coord: [1106.  135. 1206.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1206.0 < 1264
# Coord: [911. 150. 993. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 150. 993. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  2
# Coord: [715.  86. 826. 380.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:715.0 > 620
# coord[2]>q[2]:826.0 < 915
# Coord: [715.  86. 826. 380.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:715.0 > 1000
# coord[2]>q[2]:826.0 < 1264
# Coord: [1106.  135. 1207.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1106.  135. 1207.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  3
# Coord: [719.  85. 826. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:719.0 > 620
# coord[2]>q[2]:826.0 < 915
# Coord: [719.  85. 826. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:719.0 > 1000
# coord[2]>q[2]:826.0 < 1264
# Coord: [1106.  134. 1207.  409.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:1106.0 > 620
# coord[2]>q[2]:1207.0 < 915
# Coord: [1106.  134. 1207.  409.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:1106.0 > 1000
# coord[2]>q[2]:1207.0 < 1264
# Coord: [911. 148. 993. 381.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:993.0 < 915
# Coord: [911. 148. 993. 381.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:993.0 < 1264
# Total People in frame = 3
# Number of people in queue = {1: 3, 2: 3}
# Queues len:  2
# Coords len:  2
# Coord: [720.  85. 824. 380.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:720.0 > 620
# coord[2]>q[2]:824.0 < 915
# Coord: [720.  85. 824. 380.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:720.0 > 1000
# coord[2]>q[2]:824.0 < 1264
# Coord: [911. 151. 994. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:911.0 > 620
# coord[2]>q[2]:994.0 < 915
# Coord: [911. 151. 994. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:911.0 > 1000
# coord[2]>q[2]:994.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  2
# Coord: [715.  84. 823. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:715.0 > 620
# coord[2]>q[2]:823.0 < 915
# Coord: [715.  84. 823. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:715.0 > 1000
# coord[2]>q[2]:823.0 < 1264
# Coord: [909. 150. 996. 380.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:996.0 < 915
# Coord: [909. 150. 996. 380.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:996.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  2
# Coord: [716.  84. 821. 383.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:716.0 > 620
# coord[2]>q[2]:821.0 < 915
# Coord: [716.  84. 821. 383.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:716.0 > 1000
# coord[2]>q[2]:821.0 < 1264
# Coord: [909. 149. 997. 379.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:997.0 < 915
# Coord: [909. 149. 997. 379.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:997.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  2
# Coord: [715.  84. 819. 382.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:715.0 > 620
# coord[2]>q[2]:819.0 < 915
# Coord: [715.  84. 819. 382.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:715.0 > 1000
# coord[2]>q[2]:819.0 < 1264
# Coord: [909. 149. 997. 385.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:997.0 < 915
# Coord: [909. 149. 997. 385.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:997.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  2
# Coord: [714.  83. 817. 377.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:714.0 > 620
# coord[2]>q[2]:817.0 < 915
# Coord: [714.  83. 817. 377.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:714.0 > 1000
# coord[2]>q[2]:817.0 < 1264
# Coord: [ 909.  148. 1002.  387.]
# Queue: [620   1 915 562]
# coord[0]>q[0]:909.0 > 620
# coord[2]>q[2]:1002.0 < 915
# Coord: [ 909.  148. 1002.  387.]
# Queue: [1000    1 1264  461]
# coord[0]>q[0]:909.0 > 1000
# coord[2]>q[2]:1002.0 < 1264
# Total People in frame = 2
# Number of people in queue = {1: 2, 2: 2}
# Queues len:  2
# Coords len:  0
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/retail/
# results/retail/cpu/
# results/retail/cpu/stats.txt
# results/retail/cpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:55: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Retail CPU', ['results/retail/cpu/output_video.mp4'])
# Out:
# <h5>Retail CPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/retail/cpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.2: Submit to an Edge Compute Node with a CPU and IGPU
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank* 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel® Core i5-6500TE</a>. The inference workload should run on the **Intel® HD Graphics 530** integrated GPU.

# %%
#Submit job to the queue
gpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-hd-530 -F "/data/models/intel/person-detection-retail-0013/FP32/person-detection-retail-0013 GPU /data/resources/retail.mp4 /data/queue_param/retail.npy /output/results/retail/gpu 5" -N store_core 

print(gpu_job_id[0])
# Out:
# 6GINMi7PtBoatGHiJK8HPVfNYDERN6IB

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(gpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:6GINMi7PtBoatGHiJK8HPVfNYDERN6IB) are ready.
# Please wait...................................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/retail/
# results/retail/gpu/
# results/retail/gpu/stats.txt
# results/retail/gpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Retail GPU', ['results/retail/gpu/output_video.mp4'])
# Out:
# <h5>Retail GPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/retail/gpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.3: Submit to an Edge Compute Node with an Intel® Neural Compute Stick 2
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core i5-6500te CPU</a>. The inference workload should run on an <a
#     href="https://software.intel.com/en-us/neural-compute-stick">Intel Neural Compute Stick 2</a> installed in this  node.

# %%
#Submit job to the queue
vpu_job_id = !qsub queue_job.sh -d . -l nodes=tank-870:i5-6500te:intel-ncs2  -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 MYRIAD /data/resources/retail.mp4 /data/queue_param/retail.npy /output/results/retail/vpu 5" -N store_core

print(vpu_job_id[0])
# Out:
# bHrmIYkz6QilOTSPeBjpPfymAo5pIIAf

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(vpu_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:bHrmIYkz6QilOTSPeBjpPfymAo5pIIAf) are ready.
# Please wait...........................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# Loading Network...
# Network loaded.
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/retail/
# results/retail/vpu/
# results/retail/vpu/stats.txt
# results/retail/vpu/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Retail VPU', ['results/retail/vpu/output_video.mp4'])
# Out:
# <h5>Retail VPU</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/retail/vpu/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ## Step 1.4: Submit to an Edge Compute Node with IEI Mustang-F100-A10
# In the cell below, write a script to submit a job to an <a
#     href="https://software.intel.com/en-us/iot/hardware/iei-tank-dev-kit-core">IEI
#     Tank 870-Q170</a> edge node with an <a href="https://ark.intel.com/products/88186/Intel-Core-i5-6500TE-Processor-6M-Cache-up-to-3-30-GHz-">Intel Core™ i5-6500te CPU</a> . The inference workload will run on the <a href="https://www.ieiworld.com/mustang-f100/en/"> IEI Mustang-F100-A10 </a> FPGA card installed in this node.

# %%
#Submit job to the queue
fpga_job_id = !qsub queue_job.sh -d . -l nodes=1:tank-870:i5-6500te:iei-mustang-f100-a10 -F "/data/models/intel/person-detection-retail-0013/FP16/person-detection-retail-0013 HETERO:FPGA,CPU /data/resources/retail.mp4 /data/queue_param/retail.npy /output/results/retail/fpga 5" -N store_core

print(fpga_job_id[0])
# Out:
# PhFjfI4VIK3zoh2gJ2nNXb98Ybg2f5U2

# %% [markdown]
# ### Check Job Status
#
# To check on the job that was submitted, use `liveQStat` to check the status of the job.
#
# Column `S` shows the state of your running jobs.
#
# For example:
# - If `JOB ID`is in Q state, it is in the queue waiting for available resources.
# - If `JOB ID` is in R state, it is running.

# %%
import liveQStat
liveQStat.liveQStat()

# %% [markdown]
# #### Get Results
#
# Run the next cell to retrieve your job's results.

# %%
import get_results
get_results.getResults(fpga_job_id[0], filename='output.tgz', blocking=True)
# Out:
# getResults() is blocking until results of the job (id:PhFjfI4VIK3zoh2gJ2nNXb98Ybg2f5U2) are ready.
# Please wait.................................................Success!
# output.tgz was downloaded in the same folder as this notebook.

# %% [markdown]
# #### Unpack your output files and view stdout.log

# %%
# !tar zxf output.tgz

# %%
# !cat stdout.log
# Out:
# INTELFPGAOCLSDKROOT is not set
# Using script's current directory (/opt/altera/aocl-pro-rte/aclrte-linux64)
#
# aoc was not found, but aocl was found. Assuming only RTE is installed.
#
# AOCL_BOARD_PACKAGE_ROOT is set to /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2. Using that.
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/bin to PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/altera/aocl-pro-rte/aclrte-linux64/host/linux64/lib to LD_LIBRARY_PATH
# Adding /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/lib to LD_LIBRARY_PATH
# aocl program: Running program from /opt/intel/openvino/bitstreams/a10_vision_design_sg2_bitstreams/BSP/a10_1150_sg2/linux64/libexec
# Programming device: a10gx_2ddr : Intel Vision Accelerator Design with Intel Arria 10 FPGA (acla10_1150_sg20)
# Program succeed.
# Loading Network...
# Network loaded.
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 6
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 5
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 2, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 4
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 3
# Number of people in queue = {1: 1, 2: 1}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 2
# Number of people in queue = {1: 1, 2: 0}
# Total People in frame = 0
# Number of people in queue = {1: 0, 2: 0}
# results/
# results/retail/
# results/retail/fpga/
# results/retail/fpga/stats.txt
# results/retail/fpga/output_video.mp4
# stderr.log

# %% [markdown]
# #### View stderr.log
# This can be used for debugging

# %%
# !cat stderr.log
# Out:
# person_detect.py:60: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   self.model=IENetwork(self.model_structure, self.model_weights)

# %% [markdown]
# #### View Output Video
# Run the cell below to view the output video. If inference was successfully run, you should see a video with bounding boxes drawn around each person detected.

# %%
import videoHtml

videoHtml.videoHTML('Retail FPGA', ['results/retail/fpga/output_video.mp4'])
# Out:
# <h5>Retail FPGA</h5>
#         <video alt="" controls autoplay muted height="480"><source src="results/retail/fpga/output_video.mp4" type="video/mp4" /></video>

# %% [markdown]
# ***Wait!***
#
# Please wait for all the inference jobs and video rendering to complete before proceeding to the next step.
#
# ## Step 2: Assess Performance
#
# Run the cells below to compare the performance across all 4 devices. The following timings for the model are being comapred across all 4 devices:
#
# - Model Loading Time
# - Average Inference Time
# - FPS

# %%
import matplotlib.pyplot as plt

device_list=['cpu', 'gpu', 'fpga', 'vpu']
inference_time=[]
fps=[]
model_load_time=[]

for device in device_list:
    with open('results/retail/'+device+'/stats.txt', 'r') as f:
        inference_time.append(float(f.readline().split("\n")[0]))
        fps.append(float(f.readline().split("\n")[0]))
        model_load_time.append(float(f.readline().split("\n")[0]))

# %%
plt.bar(device_list, inference_time)
plt.xlabel("Device Used")
plt.ylabel("Total Inference Time in Seconds")
plt.show()

# %%
plt.bar(device_list, fps)
plt.xlabel("Device Used")
plt.ylabel("Frames per Second")
plt.show()

# %%
plt.bar(device_list, model_load_time)
plt.xlabel("Device Used")
plt.ylabel("Model Loading Time in Seconds")
plt.show()

# %% [markdown]
# # Step 3: Update Proposal Document
#
# Now that you've completed your hardware testing, you should go back to the proposal document and validate or update your originally proposed hardware. Once you've updated your proposal, you can move onto the next scenario.
